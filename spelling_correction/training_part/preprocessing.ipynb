# %%
import pandas as pd
import numpy as np
import itertools
import random

# %%
# dataset = pd.read_csv("./datasets/dict.csv")
# words = dataset["word"]
# words = list(set(words.to_numpy()))
# words = [item for item in words if isinstance(item, str) and len(item)>2]

# %%
words = ['cattle', 'beautiful', 'input', 'daring', 'predict', 'giraffe', 'blend', 'simplify', 'knack', 'parent', 'elevate', 'incentive', 'gather', 'clumsy', 'zoom', 'aluminum', 'example', 'town', 'clerk', 'work', 'disease', 'solve', 'change', 'flavor', 'vase', 'attach', 'assemble', 'interest', 'react', 'wince', 'show', 'sensitive', 'mount', 'luck', 'wager', 'pretty', 'aspect', 'camera', 'zodiac', 'zinc', 'explore', 'mile', 'grid', 'poor', 'violent', 'absorb', 'desire', 'zero', 'charitable', 'tolerate', 'doubt', 'guitar', 'enrich', 'clamp', 'across', 'active', 'friend', 'feature', 'never', 'blanket', 'middle', 'flood', 'kitchen', 'candidate', 'cease', 'leads', 'bravery', 'rescue', 'outdoor', 'update', 'trust', 'neutral', 'mobile', 'roam', 'dance', 'bitter', 'energy', 'together', 'discover', 'couch', 'link', 'model', 'finance', 'citizen', 'horizon', 'cliff', 'ability', 'cool', 'latter', 'exhibit', 'relate', 'crisis', 'enemy', 'arrange', 'project', 'rate', 'zone', 'visit', 'combine', 'athlete', 'clock', 'hurdle', 'banker', 'brisk', 'stranger', 'buy', 'skip', 'assess', 'carbon', 'console', 'alike', 'waste', 'expect', 'emerge', 'drink', 'house', 'false', 'death', 'youth', 'rival', 'explode', 'wonder', 'heart', 'myth', 'tension', 'charm', 'expose', 'result', 'stabilize', 'synthesis', 'jumpy', 'excel', 'community', 'combat', 'error', 'bake', 'return', 'record', 'accept', 'meadow', 'create', 'bottle', 'favor', 'private', 'actor', 'demand', 'dear', 'chamber', 'warn', 'puppet', 'academy', 'collect', 'store', 'worse', 'variable', 'ride', 'human', 'excited', 'text', 'vote', 'debt', 'yearly', 'natural', 'improve', 'imagine', 'occupy', 'stuck', 'flame', 'forward', 'society', 'your', 'jump', 'mental', 'volume', 'advance', 'lacks', 'yell', 'judge', 'cage', 'hospital', 'billion', 'barrier', 'primary', 'season', 'clean', 'spirit', 'grace', 'crown', 'leader', 'court', 'winter', 'formula', 'run', 'stiff', 'shelter', 'depth', 'peach', 'resource', 'engage', 'mention', 'better', 'dangerous', 'review', 'obtain', 'noble', 'clue', 'truth', 'stare', 'attack', 'student', 'health', 'agency', 'literary', 'average', 'wish', 'action', 'accuse', 'abuse', 'yellow', 'common', 'bicycle', 'habit', 'smell', 'impress', 'quality', 'profit', 'trade', 'mild', 'clash', 'place', 'wheel', 'listen', 'fitness', 'eternal', 'order', 'fluent', 'tourist', 'picture', 'shine', 'fishing', 'social', 'stress', 'whole', 'bargain', 'bizarre', 'chill', 'survive', 'calibrate', 'biology', 'appliance', 'foolish', 'kite', 'cloud', 'nature', 'tender', 'image', 'exact', 'vacation', 'reduce', 'universe', 'amount', 'experiment', 'limit', 'humor', 'front', 'apply', 'anxiety', 'artist', 'bricks', 'post', 'belief', 'journal', 'public', 'noir', 'fantastic', 'garden', 'future', 'yoga', 'select', 'object', 'effect', 'toll', 'element', 'vary', 'diverse', 'approach', 'allege', 'navigate', 'start', 'begin', 'morning', 'choice', 'approve', 'smart', 'elate', 'airport', 'angry', 'balloon', 'single', 'justify', 'fruit', 'vast', 'further', 'become', 'support', 'school', 'mind', 'compete', 'government', 'anniversary', 'notable', 'agree', 'utility', 'essay', 'control', 'position', 'value', 'voice', 'class', 'custom', 'issue', 'mature', 'symbol', 'lemon', 'joke', 'doubtful', 'blink', 'council', 'snow', 'restore', 'edgy', 'group', 'honor', 'allergy', 'tackle', 'plane', 'piano', 'adapt', 'earth', 'damage', 'neat', 'believe', 'transport', 'allegiance', 'option', 'danger', 'test', 'cherry', 'study', 'welcome', 'reason', 'total', 'trouble', 'fact', 'commerce', 'jolly', 'vision', 'program', 'system', 'enforce', 'cheap', 'vivid', 'mansion', 'table', 'found', 'knight', 'yarn', 'aware', 'advice', 'verify', 'cancer', 'company', 'commodity', 'lives', 'impact', 'account', 'outcome', 'respect', 'mob', 'runway', 'architecture', 'careful', 'outline', 'trick', 'chance', 'silent', 'badly', 'workshop', 'address', 'affect', 'life', 'focus', 'today', 'celebrate', 'weary', 'entry', 'near', 'excuse', 'decade', 'unit', 'quote', 'allies', 'notice', 'water', 'other', 'wave', 'argue', 'clarify', 'classic', 'journey', 'calm', 'guard', 'sense', 'beyond', 'migrate', 'applause', 'beauty', 'accident', 'brother', 'alter', 'threat', 'reach', 'duty', 'bachelor', 'mice', 'brown', 'plenty', 'absence', 'union', 'price', 'roar', 'deficit', 'move', 'policy', 'joyful', 'density', 'banish', 'virus', 'river', 'taste', 'climate', 'event', 'king', 'equal', 'moment', 'target', 'cube', 'yes', 'logic', 'gesture', 'true', 'stock', 'divide', 'western', 'laugh', 'minute', 'celestial', 'rain', 'open', 'moral', 'devil', 'expand', 'mail', 'prove', 'type', 'access', 'remove', 'budget', 'peace', 'witness', 'asset', 'delicate', 'pulse', 'charter', 'point', 'inspire', 'anger', 'difference', 'grate', 'freedom', 'comet', 'station', 'current', 'juror', 'already', 'tooth', 'personal', 'outer', 'partner', 'suffer', 'ideal', 'knee', 'older', 'color', 'close', 'tempt', 'walk', 'obese', 'mourn', 'assault', 'worker', 'harsh', 'scare', 'adopt', 'ready', 'dominate', 'happen', 'absent', 'privacy', 'ignore', 'magic', 'method', 'scale', 'settle', 'host', 'fashion', 'debate', 'gender', 'tonight', 'breathe', 'guilt', 'cycle', 'moat', 'vibe', 'teeth', 'unite', 'against', 'analysis', 'chicken', 'bother', 'mask', 'global', 'trend', 'analyze', 'nail', 'provoke', 'cabin', 'assistant', 'unique', 'rosy', 'slope', 'street', 'ancient', 'abandon', 'step', 'sick', 'deal', 'yesterday', 'array', 'march', 'defend', 'dungeon', 'pattern', 'round', 'majority', 'motel', 'smooth', 'adult', 'appeal', 'sound', 'bring', 'recall', 'ladder', 'culture', 'design', 'news', 'dialogue', 'oxygen', 'alert', 'almost', 'torch', 'whisper', 'hike', 'separate', 'learn', 'market', 'label', 'catch', 'final', 'dreamer', 'handle', 'buyer', 'brief', 'forecast', 'cousin', 'acquire', 'second', 'query', 'agile', 'knock', 'power', 'advantage', 'fine', 'lender', 'pet', 'capture', 'orange', 'planet', 'june', 'fetch', 'flock', 'zebra', 'brand', 'occasions', 'team', 'kiss']

# %%
def generate_all_misspellings(word):
    word = str(word)
    if len(word) < 2:
        return [word]  
    
    word = list(word)
    possible_misspellings = set()
    
    for indices in itertools.combinations(range(len(word)), 2):
        word_copy = word[:]
        
        # Swap
        swapped = word_copy[:]
        swapped[indices[0]], swapped[indices[1]] = swapped[indices[1]], swapped[indices[0]]
        possible_misspellings.add("".join(swapped))
        
        # Replace
        for i in indices:
            for char in "abcdefghijklmnopqrstuvwxyz":
                replaced = word_copy[:]
                replaced[i] = char
                possible_misspellings.add("".join(replaced))
        
        # Delete
        deleted = word_copy[:]
        for i in sorted(indices, reverse=True):
            del deleted[i]
        possible_misspellings.add("".join(deleted))
        
        # Insert
        for i in indices:
            for char in "abcdefghijklmnopqrstuvwxyz":
                inserted = word_copy[:]
                inserted.insert(i, char)
                possible_misspellings.add("".join(inserted))
    
    return list(possible_misspellings)

# %%
data = [[word, misspelling, 0] for word in words for misspelling in generate_all_misspellings(word)]
# half_size = len(data) // 2
# data = random.sample(data, half_size)

# %%
def generate_totally_incorrect_pairs(words, num_pairs_min=200, num_pairs_max=220):
    different_words = []
    for idx, word in enumerate(words):
        other_words = words[:idx] + words[idx+1:]  
        num_pairs = random.randint(num_pairs_min, num_pairs_max)
        random_250_words = random.sample(other_words, num_pairs)
        for other_word in random_250_words:
            different_words.append([word, other_word, 1])
    return different_words

# %%
totally_different_words = generate_totally_incorrect_pairs(words)

# %%
combined_data = totally_different_words + data
random.shuffle(combined_data)
combined_data
# Out:
# [['grace', 'hospital', 1],
#  ['journal', 'journzl', 0],
#  ['hospital', 'edgy', 1],
#  ['freedom', 'freedkom', 0],
#  ['exact', 'exbct', 0],
#  ['event', 'cage', 1],
#  ['knock', 'knoock', 0],
#  ['engage', 'engagve', 0],
#  ['noble', 'nocble', 0],
#  ['taste', 'allergy', 1],
#  ['threat', 'threalt', 0],
#  ['dangerous', 'dangeroys', 0],
#  ['volume', 'universe', 1],
#  ['better', 'bettemr', 0],
#  ['compete', 'fluent', 1],
#  ['address', 'adkdress', 0],
#  ['mount', 'moundt', 0],
#  ['choice', 'forecast', 1],
#  ['dangerous', 'dpangerous', 0],
#  ['guard', 'affect', 1],
#  ['zone', 'nzone', 0],
#  ['freedom', 'frfeedom', 0],
#  ['notable', 'xotable', 0],
#  ['assistant', 'bicycle', 1],
#  ['elevate', 'elevawe', 0],
#  ['aluminum', 'aluminur', 0],
#  ['moment', 'anxiety', 1],
#  ['natural', 'naturaxl', 0],
#  ['fine', 'rescue', 1],
#  ['blend', 'bwlend', 0],
#  ['clean', 'ceean', 0],
#  ['voice', 'work', 1],
#  ['crisis', 'yearly', 1],
#  ['plenty', 'plfenty', 0],
#  ['decade', 'listen', 1],
#  ['solve', 'ssolve', 0],
#  ['target', 'tparget', 0],
#  ['candidate', 'cmndidate', 0],
#  ['banker', 'method', 1],
#  ['workshop', 'wokrkshop', 0],
#  ['logic', 'logaic', 0],
#  ['clash', 'vlash', 0],
#  ['option', 'moption', 0],
#  ['accident', 'your', 1],
#  ['common', 'lives', 1],
#  ['primary', 'primazry', 0],
#  ['neutral', 'nbeutral', 0],
#  ['budget', 'bpdget', 0],
#  ['habit', 'cherry', 1],
#  ['smart', 'bricks', 1],
#  ['allegiance', 'allegiaznce', 0],
#  ['debate', 'anxiety', 1],
#  ['climate', 'walk', 1],
#  ['common', 'cmmo', 0],
#  ['input', 'inpug', 0],
#  ['cabin', 'capbin', 0],
#  ['drink', 'drind', 0],
#  ['vision', 'program', 1],
#  ['chill', 'chipl', 0],
#  ['position', 'pnsitioo', 0],
#  ['cattle', 'lattle', 0],
#  ['bother', 'bokher', 0],
#  ['flame', 'flyme', 0],
#  ['believe', 'behlieve', 0],
#  ['majority', 'emajority', 0],
#  ['absence', 'adsence', 0],
#  ['anxiety', 'anxjety', 0],
#  ['absent', 'aksent', 0],
#  ['collect', 'stress', 1],
#  ['buy', 'ancient', 1],
#  ['aluminum', 'excuse', 1],
#  ['support', 'academy', 1],
#  ['peace', 'heace', 0],
#  ['quality', 'qcuality', 0],
#  ['project', 'projecw', 0],
#  ['control', 'gather', 1],
#  ['school', 'change', 1],
#  ['charitable', 'charfitable', 0],
#  ['asset', 'assep', 0],
#  ['whole', 'whoae', 0],
#  ['expand', 'judge', 1],
#  ['blend', 'clock', 1],
#  ['partner', 'parteer', 0],
#  ['dangerous', 'sdangerous', 0],
#  ['excuse', 'volume', 1],
#  ['navigate', 'devil', 1],
#  ['account', 'accounjt', 0],
#  ['abuse', 'abusme', 0],
#  ['stabilize', 'stabvlize', 0],
#  ['post', 'bother', 1],
#  ['desire', 'ldesire', 0],
#  ['buyer', 'asset', 1],
#  ['classic', 'czlassic', 0],
#  ['listen', 'plisten', 0],
#  ['tolerate', 'toleraze', 0],
#  ['social', 'sjocial', 0],
#  ['rival', 'attach', 1],
#  ['believe', 'delieve', 0],
#  ['stock', 'sjtock', 0],
#  ['arrange', 'arramnge', 0],
#  ['found', 'feund', 0],
#  ['candidate', 'candadate', 0],
#  ['expose', 'expost', 0],
#  ['create', 'crveate', 0],
#  ['symbol', 'finance', 1],
#  ['stuck', 'death', 1],
#  ['death', 'eth', 0],
#  ['calm', 'object', 1],
#  ['mourn', 'dmourn', 0],
#  ['smooth', 'excited', 1],
#  ['vision', 'bricks', 1],
#  ['brisk', 'brirsk', 0],
#  ['season', 'clock', 1],
#  ['action', 'acftion', 0],
#  ['zebra', 'zebrv', 0],
#  ['wish', 'vision', 1],
#  ['essay', 'essaby', 0],
#  ['doubtful', 'event', 1],
#  ['western', 'friend', 1],
#  ['already', 'learn', 1],
#  ['joyful', 'close', 1],
#  ['incentive', 'incelntive', 0],
#  ['advice', 'health', 1],
#  ['mile', 'unite', 1],
#  ['attack', 'vision', 1],
#  ['tourist', 'public', 1],
#  ['learn', 'gearn', 0],
#  ['result', 'resrult', 0],
#  ['accuse', 'accuzse', 0],
#  ['gather', 'gathjer', 0],
#  ['tender', 'select', 1],
#  ['doubt', 'douzt', 0],
#  ['biology', 'biolpgy', 0],
#  ['sense', 'sensx', 0],
#  ['density', 'adult', 1],
#  ['analyze', 'analyzue', 0],
#  ['assess', 'ahsess', 0],
#  ['lender', 'lend', 0],
#  ['option', 'winter', 1],
#  ['social', 'soctal', 0],
#  ['average', 'avage', 0],
#  ['fluent', 'march', 1],
#  ['restore', 'kitchen', 1],
#  ['biology', 'giraffe', 1],
#  ['ladder', 'laddex', 0],
#  ['crown', 'defend', 1],
#  ['stranger', 'relate', 1],
#  ['cabin', 'coabin', 0],
#  ['camera', 'camlera', 0],
#  ['buyer', 'buyor', 0],
#  ['banish', 'banuish', 0],
#  ['flavor', 'flayvor', 0],
#  ['input', 'tinput', 0],
#  ['noble', 'mob', 1],
#  ['cloud', 'cvoud', 0],
#  ['vision', 'visioon', 0],
#  ['flock', 'ftock', 0],
#  ['company', 'comopany', 0],
#  ['brown', 'brosn', 0],
#  ['outdoor', 'outdoos', 0],
#  ['utility', 'utiiy', 0],
#  ['orange', 'scare', 1],
#  ['fact', 'moat', 1],
#  ['water', 'waoer', 0],
#  ['clash', 'dclash', 0],
#  ['visit', 'visnt', 0],
#  ['garden', 'reach', 1],
#  ['giraffe', 'station', 1],
#  ['element', 'eemen', 0],
#  ['academy', 'acadeqmy', 0],
#  ['natural', 'nayural', 0],
#  ['assemble', 'neat', 1],
#  ['disease', 'disemase', 0],
#  ['already', 'enrich', 1],
#  ['calibrate', 'calibratie', 0],
#  ['adapt', 'vibe', 1],
#  ['beyond', 'beypond', 0],
#  ['ignore', 'ignure', 0],
#  ['calm', 'caclm', 0],
#  ['beyond', 'beymnd', 0],
#  ['focus', 'foocus', 0],
#  ['explore', 'control', 1],
#  ['tempt', 'tempe', 0],
#  ['found', 'founvd', 0],
#  ['almost', 'walmost', 0],
#  ['government', 'imagine', 1],
#  ['return', 'forecast', 1],
#  ['gender', 'grnder', 0],
#  ['place', 'plabce', 0],
#  ['fetch', 'fmetch', 0],
#  ['happen', 'barrier', 1],
#  ['clash', 'las', 0],
#  ['run', 'rjn', 0],
#  ['stress', 'vacation', 1],
#  ['water', 'effect', 1],
#  ['alert', 'average', 1],
#  ['resource', 'knee', 1],
#  ['abuse', 'aquse', 0],
#  ['silent', 'academy', 1],
#  ['console', 'coonsole', 0],
#  ['separate', 'youth', 1],
#  ['cancer', 'exhibit', 1],
#  ['incentive', 'meadow', 1],
#  ['aware', 'awarhe', 0],
#  ['yellow', 'navigate', 1],
#  ['clumsy', 'cnumsy', 0],
#  ['address', 'social', 1],
#  ['error', 'lerror', 0],
#  ['issue', 'isslue', 0],
#  ['wonder', 'analysis', 1],
#  ['choice', 'vchoice', 0],
#  ['student', 'studenit', 0],
#  ['explore', 'explfre', 0],
#  ['barrier', 'bahrier', 0],
#  ['river', 'rivey', 0],
#  ['divide', 'wheel', 1],
#  ['element', 'dreamer', 1],
#  ['together', 'tzgether', 0],
#  ['brisk', 'srisk', 0],
#  ['discover', 'cdiscover', 0],
#  ['mourn', 'myourn', 0],
#  ['vase', 'vzase', 0],
#  ['classic', 'anniversary', 1],
#  ['remove', 'remdove', 0],
#  ['model', 'biology', 1],
#  ['control', 'controhl', 0],
#  ['further', 'fuhtrer', 0],
#  ['calibrate', 'caqlibrate', 0],
#  ['impact', 'imtact', 0],
#  ['select', 'oxygen', 1],
#  ['death', 'wince', 1],
#  ['privacy', 'alert', 1],
#  ['limit', 'limint', 0],
#  ['across', 'flavor', 1],
#  ['house', 'become', 1],
#  ['welcome', 'zodiac', 1],
#  ['combine', 'tension', 1],
#  ['explode', 'weary', 1],
#  ['cage', 'qage', 0],
#  ['celestial', 'aware', 1],
#  ['cherry', 'banish', 1],
#  ['virus', 'culture', 1],
#  ['pretty', 'prxetty', 0],
#  ['assault', 'assaalt', 0],
#  ['amount', 'amkunt', 0],
#  ['console', 'monsole', 0],
#  ['athlete', 'afhlete', 0],
#  ['bricks', 'mental', 1],
#  ['dear', 'dekar', 0],
#  ['asset', 'azsset', 0],
#  ['spirit', 'human', 1],
#  ['rosy', 'rjosy', 0],
#  ['collect', 'journey', 1],
#  ['waste', 'wastd', 0],
#  ['trick', 'expect', 1],
#  ['expose', 'exrose', 0],
#  ['cease', 'rate', 1],
#  ['cliff', 'clviff', 0],
#  ['roam', 'roat', 0],
#  ['notice', 'nzotice', 0],
#  ['government', 'govaernment', 0],
#  ['architecture', 'architectqure', 0],
#  ['occasions', 'minute', 1],
#  ['peach', 'peacdh', 0],
#  ['equal', 'freedom', 1],
#  ['human', 'htuman', 0],
#  ['fact', 'faqct', 0],
#  ['jumpy', 'juompy', 0],
#  ['blink', 'blihk', 0],
#  ['quote', 'qduote', 0],
#  ['allegiance', 'alleguance', 0],
#  ['other', 'othehr', 0],
#  ['sensitive', 'sensitzive', 0],
#  ['allergy', 'tackle', 1],
#  ['survive', 'survvive', 0],
#  ['parent', 'parejt', 0],
#  ['vacation', 'near', 1],
#  ['foolish', 'assemble', 1],
#  ['commodity', 'commudity', 0],
#  ['agency', 'ageuncy', 0],
#  ['literary', 'listerary', 0],
#  ['wager', 'scale', 1],
#  ['lives', 'livefs', 0],
#  ['record', 'recorgd', 0],
#  ['scare', 'szare', 0],
#  ['street', 'stdeet', 0],
#  ['variable', 'vqariable', 0],
#  ['wave', 'impact', 1],
#  ['horizon', 'korizon', 0],
#  ['cheap', 'cieap', 0],
#  ['round', 'rould', 0],
#  ['brother', 'zbrother', 0],
#  ['yellow', 'yeldow', 0],
#  ['discover', 'diszcover', 0],
#  ['combine', 'cvmbine', 0],
#  ['suffer', 'suffhr', 0],
#  ['alter', 'favor', 1],
#  ['juror', 'ajuror', 0],
#  ['disease', 'debate', 1],
#  ['tender', 'tenwder', 0],
#  ['deal', 'allies', 1],
#  ['juror', 'jurox', 0],
#  ['bizarre', 'vast', 1],
#  ['horizon', 'horizox', 0],
#  ['mind', 'minf', 0],
#  ['trouble', 'troublpe', 0],
#  ['incentive', 'demand', 1],
#  ['dialogue', 'dialogule', 0],
#  ['demand', 'demdna', 0],
#  ['river', 'march', 1],
#  ['text', 'tlext', 0],
#  ['example', 'sensitive', 1],
#  ['freedom', 'entry', 1],
#  ['yarn', 'yary', 0],
#  ['bother', 'mail', 1],
#  ['trade', 'traje', 0],
#  ['vivid', 'plane', 1],
#  ['option', 'optimon', 0],
#  ['profit', 'proxit', 0],
#  ['journey', 'universe', 1],
#  ['personal', 'pedrsonal', 0],
#  ['earth', 'earteh', 0],
#  ['incentive', 'ingentive', 0],
#  ['welcome', 'welcoeme', 0],
#  ['tension', 'tensiov', 0],
#  ['dominate', 'actor', 1],
#  ['western', 'charter', 1],
#  ['flavor', 'feature', 1],
#  ['across', 'asrocs', 0],
#  ['trade', 'tvade', 0],
#  ['project', 'projeht', 0],
#  ['flock', 'mlock', 0],
#  ['unite', 'utite', 0],
#  ['clerk', 'resource', 1],
#  ['recall', 'retcall', 0],
#  ['community', 'communicy', 0],
#  ['tonight', 'climate', 1],
#  ['applause', 'bicycle', 1],
#  ['cycle', 'cyjcle', 0],
#  ['aware', 'zodiac', 1],
#  ['feature', 'feaiture', 0],
#  ['blend', 'bhlend', 0],
#  ['youth', 'culture', 1],
#  ['journey', 'advice', 1],
#  ['lemon', 'lemin', 0],
#  ['personal', 'plrsonae', 0],
#  ['mansion', 'maion', 0],
#  ['exact', 'exacy', 0],
#  ['balloon', 'ballsoon', 0],
#  ['fruit', 'qfruit', 0],
#  ['favor', 'fsavor', 0],
#  ['yell', 'joyful', 1],
#  ['sense', 'sensy', 0],
#  ['forecast', 'fworecast', 0],
#  ['smart', 'cool', 1],
#  ['project', 'visit', 1],
#  ['trust', 'eternal', 1],
#  ['advance', 'absent', 1],
#  ['beyond', 'console', 1],
#  ['threat', 'symbol', 1],
#  ['attach', 'atcach', 0],
#  ['sense', 'sdense', 0],
#  ['fruit', 'frt', 0],
#  ['life', 'adapt', 1],
#  ['scare', 'scajre', 0],
#  ['buyer', 'ignore', 1],
#  ['knock', 'ksnock', 0],
#  ['clue', 'fetch', 1],
#  ['open', 'oepn', 0],
#  ['breathe', 'breajhe', 0],
#  ['yearly', 'yvearly', 0],
#  ['flame', 'fqlame', 0],
#  ['outer', 'fruit', 1],
#  ['vacation', 'vacajtion', 0],
#  ['listen', 'suffer', 1],
#  ['season', 'seasosn', 0],
#  ['sense', 'senshe', 0],
#  ['athlete', 'pretty', 1],
#  ['team', 'beautiful', 1],
#  ['commodity', 'ccmmodity', 0],
#  ['together', 'togethedr', 0],
#  ['ability', 'fability', 0],
#  ['imagine', 'incentive', 1],
#  ['banker', 'canker', 0],
#  ['wager', 'wager', 0],
#  ['older', 'eldor', 0],
#  ['council', 'kouncil', 0],
#  ['wheel', 'eel', 0],
#  ['yellow', 'abuse', 1],
#  ['joke', 'jpoke', 0],
#  ['capture', 'moat', 1],
#  ['place', 'dangerous', 1],
#  ['dear', 'dqear', 0],
#  ['celebrate', 'celebrcate', 0],
#  ['social', 'soczal', 0],
#  ['honor', 'hobnor', 0],
#  ['mice', 'dungeon', 1],
#  ['vote', 'vtte', 0],
#  ['difference', 'buyer', 1],
#  ['clock', 'natural', 1],
#  ['giraffe', 'stuck', 1],
#  ['reason', 'reamon', 0],
#  ['jump', 'start', 1],
#  ['type', 'typr', 0],
#  ['personal', 'respect', 1],
#  ['error', 'label', 1],
#  ['candidate', 'excited', 1],
#  ['mount', 'simplify', 1],
#  ['fruit', 'settle', 1],
#  ['agency', 'lagency', 0],
#  ['piano', 'zpiano', 0],
#  ['toll', 'jtoll', 0],
#  ['finance', 'ainfnce', 0],
#  ['capture', 'cqapture', 0],
#  ['student', 'respect', 1],
#  ['sick', 'elate', 1],
#  ['sick', 'common', 1],
#  ['query', 'qukery', 0],
#  ['mansion', 'marnsion', 0],
#  ['element', 'bring', 1],
#  ['show', 'compete', 1],
#  ['advice', 'element', 1],
#  ['become', 'bvecome', 0],
#  ['clarify', 'clriy', 0],
#  ['community', 'comnunity', 0],
#  ['collect', 'colmlect', 0],
#  ['recall', 'billion', 1],
#  ['impact', 'freedom', 1],
#  ['news', 'newq', 0],
#  ['affect', 'afafect', 0],
#  ['barrier', 'barriew', 0],
#  ['cheap', 'collect', 1],
#  ['smart', 'skart', 0],
#  ['luck', 'lucj', 0],
#  ['mansion', 'ransion', 0],
#  ['jumpy', 'jummpy', 0],
#  ['improve', 'imprsove', 0],
#  ['hospital', 'hospixal', 0],
#  ['barrier', 'june', 1],
#  ['vacation', 'xvacation', 0],
#  ['appeal', 'appeaql', 0],
#  ['round', 'ropnd', 0],
#  ['gender', 'gendser', 0],
#  ['social', 'query', 1],
#  ['suffer', 'yarn', 1],
#  ['beautiful', 'decade', 1],
#  ['analysis', 'aalyss', 0],
#  ['position', 'poitio', 0],
#  ['assemble', 'assenble', 0],
#  ['focus', 'breathe', 1],
#  ['brother', 'brothmer', 0],
#  ['daring', 'dading', 0],
#  ['expose', 'yxpose', 0],
#  ['volume', 'input', 1],
#  ['guard', 'guary', 0],
#  ['obtain', 'explore', 1],
#  ['yearly', 'yearlgy', 0],
#  ['piano', 'mpiano', 0],
#  ['alter', 'eltar', 0],
#  ['fishing', 'nishifg', 0],
#  ['breathe', 'breatie', 0],
#  ['point', 'koint', 0],
#  ['trick', 'tyrick', 0],
#  ['careful', 'caueful', 0],
#  ['brand', 'brnad', 0],
#  ['literary', 'ziterary', 0],
#  ['rival', 'rjval', 0],
#  ['sensitive', 'sensitire', 0],
#  ['natural', 'alter', 1],
#  ['court', 'couhrt', 0],
#  ['chance', 'chancv', 0],
#  ['voice', 'agile', 1],
#  ['start', 'reach', 1],
#  ['celebrate', 'spirit', 1],
#  ['wince', 'winve', 0],
#  ['student', 'stydent', 0],
#  ['brief', 'bqief', 0],
#  ['slope', 'sgope', 0],
#  ['scale', 'vscale', 0],
#  ['beyond', 'clumsy', 1],
#  ['assault', 'link', 1],
#  ['zebra', 'minute', 1],
#  ['yoga', 'koga', 0],
#  ['lacks', 'expose', 1],
#  ['edgy', 'harsh', 1],
#  ['tourist', 'blink', 1],
#  ['start', 'starht', 0],
#  ['whole', 'wbole', 0],
#  ['mail', 'ignore', 1],
#  ['moment', 'momment', 0],
#  ['project', 'projbct', 0],
#  ['occasions', 'belief', 1],
#  ['shine', 'shinje', 0],
#  ['vast', 'cloud', 1],
#  ['whisper', 'beautiful', 1],
#  ['minute', 'gesture', 1],
#  ['experiment', 'exprimet', 0],
#  ['target', 'targert', 0],
#  ['excuse', 'excose', 0],
#  ['dance', 'bother', 1],
#  ['impress', 'imprqss', 0],
#  ['grid', 'grik', 0],
#  ['applause', 'ppalause', 0],
#  ['desire', 'descre', 0],
#  ['volume', 'volyme', 0],
#  ['type', 'torch', 1],
#  ['deal', 'elevate', 1],
#  ['sense', 'commodity', 1],
#  ['vote', 'votl', 0],
#  ['common', 'commos', 0],
#  ['finance', 'finonce', 0],
#  ['jolly', 'accept', 1],
#  ['enrich', 'enriech', 0],
#  ['price', 'pricz', 0],
#  ['further', 'tooth', 1],
#  ['energy', 'enargy', 0],
#  ['bachelor', 'vachelor', 0],
#  ['flavor', 'ylavor', 0],
#  ['daring', 'value', 1],
#  ['private', 'mice', 1],
#  ['knack', 'finance', 1],
#  ['bravery', 'couch', 1],
#  ['moment', 'cmoment', 0],
#  ['neutral', 'neutrnal', 0],
#  ['analyze', 'array', 1],
#  ['result', 'resuglt', 0],
#  ['future', 'aluminum', 1],
#  ['ancient', 'ancienmt', 0],
#  ['synthesis', 'synuthesis', 0],
#  ['billion', 'bcllion', 0],
#  ['wish', 'elevate', 1],
#  ['return', 'regturn', 0],
#  ['barrier', 'settle', 1],
#  ['ignore', 'argue', 1],
#  ['literary', 'step', 1],
#  ['heart', 'hearp', 0],
#  ['company', 'mobile', 1],
#  ['obese', 'oeesb', 0],
#  ['beauty', 'jeauty', 0],
#  ['enforce', 'enfhorce', 0],
#  ['occupy', 'accupy', 0],
#  ['heart', 'hearkt', 0],
#  ['court', 'interest', 1],
#  ['crown', 'crovn', 0],
#  ['street', 'stcreet', 0],
#  ['celebrate', 'cewlebrate', 0],
#  ['clue', 'zlue', 0],
#  ['calibrate', 'caljibrate', 0],
#  ['banish', 'fetch', 1],
#  ['become', 'becocme', 0],
#  ['yellow', 'duty', 1],
#  ['tension', 'rival', 1],
#  ['price', 'pwice', 0],
#  ['pattern', 'pattern', 0],
#  ['compete', 'cdmpete', 0],
#  ['camera', 'amount', 1],
#  ['class', 'cla', 0],
#  ['arrange', 'adrange', 0],
#  ['privacy', 'prifvacy', 0],
#  ['cliff', 'clifa', 0],
#  ['blink', 'blmnk', 0],
#  ['mob', 'front', 1],
#  ['gesture', 'personal', 1],
#  ['compete', 'cocpete', 0],
#  ['bitter', 'hurdle', 1],
#  ['tender', 'trender', 0],
#  ['create', 'hreate', 0],
#  ['tolerate', 'tolecrate', 0],
#  ['bottle', 'botbtle', 0],
#  ['cloud', 'clound', 0],
#  ['artist', 'depth', 1],
#  ['citizen', 'artist', 1],
#  ['witness', 'flood', 1],
#  ['joyful', 'loyfuj', 0],
#  ['careful', 'carefsul', 0],
#  ['diverse', 'grace', 1],
#  ['climate', 'mature', 1],
#  ['apply', 'ypply', 0],
#  ['beautiful', 'beautivul', 0],
#  ['change', 'chanfe', 0],
#  ['house', 'hoguse', 0],
#  ['utility', 'wutility', 0],
#  ['pet', 'open', 1],
#  ['across', 'aeross', 0],
#  ['fishing', 'fishiug', 0],
#  ['mental', 'waste', 1],
#  ['outline', 'impact', 1],
#  ['june', 'juqe', 0],
#  ['utility', 'utilitqy', 0],
#  ['final', 'nal', 0],
#  ['fishing', 'mature', 1],
#  ['system', 'syltem', 0],
#  ['second', 'seconyd', 0],
#  ['advance', 'adzvance', 0],
#  ['accident', 'uaccident', 0],
#  ['appeal', 'appial', 0],
#  ['occupy', 'ocpcupy', 0],
#  ['giraffe', 'girae', 0],
#  ['trend', 'twrend', 0],
#  ['hike', 'sike', 0],
#  ['enemy', 'agile', 1],
#  ['lemon', 'ilemon', 0],
#  ['better', 'imagine', 1],
#  ['spirit', 'spinit', 0],
#  ['yell', 'yelo', 0],
#  ['angry', 'program', 1],
#  ['march', 'school', 1],
#  ['citizen', 'ciotizen', 0],
#  ['tonight', 'tohignt', 0],
#  ['imagine', 'imagini', 0],
#  ['unite', 'unfte', 0],
#  ['dialogue', 'dialoguq', 0],
#  ['finance', 'fiznance', 0],
#  ['alike', 'brother', 1],
#  ['brief', 'ubrief', 0],
#  ['learn', 'lyearn', 0],
#  ['banker', 'appeal', 1],
#  ['assemble', 'assemole', 0],
#  ['tonight', 'outline', 1],
#  ['ancient', 'ancienr', 0],
#  ['applause', 'anxiety', 1],
#  ['rate', 'sick', 1],
#  ['average', 'everage', 0],
#  ['density', 'volume', 1],
#  ['simplify', 'simpelify', 0],
#  ['noble', 'nobloe', 0],
#  ['joke', 'fantastic', 1],
#  ['silent', 'siglent', 0],
#  ['point', 'poiny', 0],
#  ['dangerous', 'test', 1],
#  ['smart', 'smarit', 0],
#  ['toll', 'wish', 1],
#  ['cycle', 'cyule', 0],
#  ['interest', 'interjest', 0],
#  ['kitchen', 'kztchen', 0],
#  ['accept', 'accepwt', 0],
#  ['kitchen', 'applause', 1],
#  ['improve', 'impzrove', 0],
#  ['gather', 'collect', 1],
#  ['banker', 'bahker', 0],
#  ['joke', 'absent', 1],
#  ['assemble', 'assvmble', 0],
#  ['sensitive', 'work', 1],
#  ['heart', 'het', 0],
#  ['acquire', 'avquire', 0],
#  ['ancient', 'anccent', 0],
#  ['difference', 'dffrence', 0],
#  ['kitchen', 'kitcheqn', 0],
#  ['literary', 'lireraty', 0],
#  ['charitable', 'charitkable', 0],
#  ['fluent', 'flueno', 0],
#  ['relate', 'rbelate', 0],
#  ['explore', 'chance', 1],
#  ['absent', 'abseng', 0],
#  ['allies', 'stress', 1],
#  ['citizen', 'ciatizen', 0],
#  ['advice', 'zdvice', 0],
#  ['zebra', 'flood', 1],
#  ['cabin', 'cazin', 0],
#  ['entry', 'nry', 0],
#  ['group', 'found', 1],
#  ['abandon', 'zodiac', 1],
#  ['tonight', 'tonpght', 0],
#  ['public', 'appliance', 1],
#  ['dreamer', 'drhamer', 0],
#  ['tender', 'tegnder', 0],
#  ['wonder', 'budget', 1],
#  ['angry', 'quote', 1],
#  ['scare', 'scarxe', 0],
#  ['humor', 'thumor', 0],
#  ['teeth', 'teeqh', 0],
#  ['debate', 'beautiful', 1],
#  ['chamber', 'chabmer', 0],
#  ['tolerate', 'tolercate', 0],
#  ['host', 'model', 1],
#  ['cease', 'order', 1],
#  ['alike', 'angry', 1],
#  ['fact', 'zfact', 0],
#  ['tackle', 'model', 1],
#  ['exact', 'grid', 1],
#  ['buy', 'laugh', 1],
#  ['kiss', 'giss', 0],
#  ['grate', 'ugrate', 0],
#  ['accident', 'acscident', 0],
#  ['dungeon', 'attack', 1],
#  ['town', 'yell', 1],
#  ['anniversary', 'aoniversary', 0],
#  ['elevate', 'elevatn', 0],
#  ['moral', 'older', 1],
#  ['puppet', 'attach', 1],
#  ['justify', 'justiqy', 0],
#  ['badly', 'badyy', 0],
#  ['occasions', 'occlasions', 0],
#  ['wish', 'ywish', 0],
#  ['utility', 'journey', 1],
#  ['orange', 'variable', 1],
#  ['government', 'citizen', 1],
#  ['cabin', 'cnbia', 0],
#  ['classic', 'ilasscc', 0],
#  ['tonight', 'taonight', 0],
#  ['suffer', 'ufer', 0],
#  ['project', 'literary', 1],
#  ['motel', 'mmtel', 0],
#  ['solve', 'sov', 0],
#  ['power', 'powier', 0],
#  ['damage', 'damajge', 0],
#  ['never', 'neqver', 0],
#  ['record', 'rerocd', 0],
#  ['adapt', 'adarpt', 0],
#  ['skip', 'siip', 0],
#  ['jump', 'jmump', 0],
#  ['wonder', 'wondtr', 0],
#  ['prove', 'proie', 0],
#  ['occupy', 'clue', 1],
#  ['academy', 'ackdemy', 0],
#  ['accept', 'court', 1],
#  ['brand', 'rosy', 1],
#  ['clock', 'cloce', 0],
#  ['yarn', 'yaen', 0],
#  ['duty', 'dudy', 0],
#  ['action', 'guilt', 1],
#  ['alert', 'nlert', 0],
#  ['banish', 'type', 1],
#  ['acquire', 'system', 1],
#  ['show', 'latter', 1],
#  ['mansion', 'limit', 1],
#  ['cabin', 'caabin', 0],
#  ['alter', 'altear', 0],
#  ['workshop', 'reduce', 1],
#  ['access', 'aqcess', 0],
#  ['teeth', 'teveth', 0],
#  ['stiff', 'zero', 1],
#  ['yearly', 'doubtful', 1],
#  ['clock', 'moral', 1],
#  ['bicycle', 'actor', 1],
#  ['tonight', 'tonigho', 0],
#  ['front', 'camera', 1],
#  ['winter', 'target', 1],
#  ['forecast', 'focast', 0],
#  ['snow', 'project', 1],
#  ['balloon', 'bballoon', 0],
#  ['project', 'projsect', 0],
#  ['sound', 'sountd', 0],
#  ['balloon', 'class', 1],
#  ['formula', 'formlla', 0],
#  ['town', 'habit', 1],
#  ['table', 'relate', 1],
#  ['fashion', 'fashieon', 0],
#  ['listen', 'ilsten', 0],
#  ['knock', 'agile', 1],
#  ['bachelor', 'chance', 1],
#  ['grid', 'grixd', 0],
#  ['trade', 'health', 1],
#  ['bottle', 'never', 1],
#  ['dangerous', 'witness', 1],
#  ['cheap', 'fruit', 1],
#  ['trust', 'run', 1],
#  ['society', 'socsiety', 0],
#  ['allergy', 'couch', 1],
#  ['experiment', 'mexperiment', 0],
#  ['order', 'limit', 1],
#  ['beauty', 'zinc', 1],
#  ['mansion', 'government', 1],
#  ['celebrate', 'celibrate', 0],
#  ['obtain', 'oitabn', 0],
#  ['rain', 'truth', 1],
#  ['cousin', 'your', 1],
#  ['freedom', 'jreedom', 0],
#  ['duty', 'partner', 1],
#  ['life', 'wife', 0],
#  ['cattle', 'cattlse', 0],
#  ['harsh', 'harsu', 0],
#  ['reach', 'zreach', 0],
#  ['attach', 'attarh', 0],
#  ['morning', 'fantastic', 1],
#  ['youth', 'yotuh', 0],
#  ['charter', 'universe', 1],
#  ['council', 'clarify', 1],
#  ['experiment', 'experimenw', 0],
#  ['earth', 'varth', 0],
#  ['advance', 'jumpy', 1],
#  ['essay', 'noir', 1],
#  ['life', 'lifde', 0],
#  ['custom', 'brand', 1],
#  ['silent', 'jolly', 1],
#  ['house', 'utility', 1],
#  ['camera', 'comera', 0],
#  ['dreamer', 'dreamrer', 0],
#  ['stuck', 'attack', 1],
#  ['mourn', 'nourm', 0],
#  ['oxygen', 'scare', 1],
#  ['enemy', 'enemb', 0],
#  ['delicate', 'exhibit', 1],
#  ['demand', 'formula', 1],
#  ['gesture', 'gestuhre', 0],
#  ['gender', 'getnder', 0],
#  ['trick', 'tridk', 0],
#  ['migrate', 'miirate', 0],
#  ['partner', 'zone', 1],
#  ['community', 'bake', 1],
#  ['zone', 'friend', 1],
#  ['march', 'mzarch', 0],
#  ['policy', 'polimcy', 0],
#  ['near', 'pattern', 1],
#  ['allies', 'allirs', 0],
#  ['fluent', 'fluepnt', 0],
#  ['synthesis', 'synthdsis', 0],
#  ['transport', 'toll', 1],
#  ['adult', 'adumt', 0],
#  ['synthesis', 'zero', 1],
#  ['assault', 'gssault', 0],
#  ['school', 'silent', 1],
#  ['bravery', 'bqavery', 0],
#  ['crisis', 'ckisis', 0],
#  ['rosy', 'nrosy', 0],
#  ['assault', 'assyault', 0],
#  ['architecture', 'archiqtecture', 0],
#  ['beautiful', 'beadutiful', 0],
#  ['adopt', 'bdopt', 0],
#  ['alike', 'aliwe', 0],
#  ['reason', 'reasno', 0],
#  ['brief', 'ignore', 1],
#  ['forecast', 'forekast', 0],
#  ['culture', 'affect', 1],
#  ['runway', 'rwnway', 0],
#  ['bravery', 'biravery', 0],
#  ['effect', 'vivid', 1],
#  ['clock', 'claock', 0],
#  ['crisis', 'crfsis', 0],
#  ['kite', 'action', 1],
#  ['approach', 'approacnh', 0],
#  ['june', 'enemy', 1],
#  ['torch', 'pulse', 1],
#  ['return', 'retwurn', 0],
#  ['allege', 'allsege', 0],
#  ['banish', 'bynish', 0],
#  ['today', 'doubtful', 1],
#  ['plane', 'policy', 1],
#  ['account', 'accpunt', 0],
#  ['change', 'cage', 0],
#  ['bizarre', 'bizanre', 0],
#  ['sensitive', 'sensftive', 0],
#  ['future', 'action', 1],
#  ['global', 'latter', 1],
#  ['support', 'suhpport', 0],
#  ['walk', 'wblk', 0],
#  ['dance', 'dxnce', 0],
#  ['collect', 'colulect', 0],
#  ['allergy', 'allerry', 0],
#  ['apply', 'wpply', 0],
#  ['zinc', 'assault', 1],
#  ['text', 'teft', 0],
#  ['today', 'blanket', 1],
#  ['change', 'phange', 0],
#  ['careful', 'carjful', 0],
#  ['label', 'believe', 1],
#  ['worker', 'bicycle', 1],
#  ['motel', 'motehl', 0],
#  ['option', 'ophtion', 0],
#  ['careful', 'cureful', 0],
#  ['knight', 'knock', 1],
#  ['budget', 'begin', 1],
#  ['mice', 'gather', 1],
#  ['agree', 'agrey', 0],
#  ['sensitive', 'senuitive', 0],
#  ['outcome', 'wutcome', 0],
#  ['imagine', 'classic', 1],
#  ['june', 'brand', 1],
#  ['stock', 'itock', 0],
#  ['address', 'addrkess', 0],
#  ['address', 'addruss', 0],
#  ['clumsy', 'action', 1],
#  ['spirit', 'spiriy', 0],
#  ['collect', 'tollecc', 0],
#  ['beauty', 'beauwy', 0],
#  ['appliance', 'applianxe', 0],
#  ['arrange', 'accuse', 1],
#  ['brown', 'relate', 1],
#  ['whisper', 'morning', 1],
#  ['hospital', 'hospityal', 0],
#  ['parent', 'weary', 1],
#  ['luck', 'mind', 1],
#  ['neutral', 'excel', 1],
#  ['commerce', 'commverce', 0],
#  ['snow', 'snoow', 0],
#  ['fruit', 'kruit', 0],
#  ['variable', 'varile', 0],
#  ['station', 'stativn', 0],
#  ['apply', 'apjly', 0],
#  ['solve', 'solvp', 0],
#  ['banish', 'clock', 1],
#  ['clumsy', 'clummsy', 0],
#  ['season', 'combat', 1],
#  ['doubtful', 'wdoubtful', 0],
#  ['label', 'eabll', 0],
#  ['school', 'current', 1],
#  ['peace', 'peacxe', 0],
#  ['mob', 'meb', 0],
#  ['choice', 'chqoice', 0],
#  ['bargain', 'barbgain', 0],
#  ['bother', 'botheh', 0],
#  ['accuse', 'agile', 1],
#  ['support', 'suort', 0],
#  ['airport', 'candidate', 1],
#  ['become', 'bejome', 0],
#  ['outdoor', 'outddoor', 0],
#  ['discover', 'ability', 1],
#  ['zoom', 'doom', 0],
#  ['billion', 'unit', 1],
#  ['stuck', 'stunk', 0],
#  ['leads', 'leadw', 0],
#  ['yellow', 'cage', 1],
#  ['power', 'apower', 0],
#  ['accident', 'deal', 1],
#  ['knock', 'actor', 1],
#  ['account', 'advance', 1],
#  ['flavor', 'flavok', 0],
#  ['program', 'prograr', 0],
#  ['run', 'meadow', 1],
#  ['honor', 'text', 1],
#  ['horizon', 'reach', 1],
#  ['yoga', 'rate', 1],
#  ['appliance', 'rppliance', 0],
#  ['calibrate', 'class', 1],
#  ['shine', 'szhine', 0],
#  ['excited', 'demand', 1],
#  ['occasions', 'occaszons', 0],
#  ['mild', 'resource', 1],
#  ['excel', 'unique', 1],
#  ['spirit', 'mpirit', 0],
#  ['target', 'targht', 0],
#  ['today', 'teeth', 1],
#  ['public', 'publiec', 0],
#  ['begin', 'begih', 0],
#  ['clarify', 'alcrify', 0],
#  ['obese', 'obexse', 0],
#  ['celestial', 'crelestial', 0],
#  ['occupy', 'occuphy', 0],
#  ['final', 'finaul', 0],
#  ['brief', 'bvrief', 0],
#  ['town', 'tvown', 0],
#  ['wave', 'wpve', 0],
#  ['resource', 'reszurce', 0],
#  ['anxiety', 'clerk', 1],
#  ['parent', 'parenct', 0],
#  ['joyful', 'oyfl', 0],
#  ['together', 'togthr', 0],
#  ['study', 'cliff', 1],
#  ['handle', 'hanule', 0],
#  ['union', 'uaion', 0],
#  ['method', 'mtthod', 0],
#  ['unit', 'unwit', 0],
#  ['respect', 'profit', 1],
#  ['moral', 'moras', 0],
#  ['desire', 'deswire', 0],
#  ['stiff', 'flame', 1],
#  ['trade', 'trafe', 0],
#  ['rain', 'rajn', 0],
#  ['artist', 'xrtist', 0],
#  ['billion', 'design', 1],
#  ['value', 'zero', 1],
#  ['close', 'plose', 0],
#  ['reduce', 'redude', 0],
#  ['sensitive', 'scnsitive', 0],
#  ['experiment', 'experimfnt', 0],
#  ['foolish', 'foolisah', 0],
#  ['project', 'eroject', 0],
#  ['deficit', 'deficibt', 0],
#  ['fact', 'journal', 1],
#  ['excuse', 'mxcuse', 0],
#  ['incentive', 'rosy', 1],
#  ['focus', 'focuss', 0],
#  ['almost', 'slmoat', 0],
#  ['peace', 'happen', 1],
#  ['mourn', 'social', 1],
#  ['rival', 'ial', 0],
#  ['power', 'stuck', 1],
#  ['mob', 'mtb', 0],
#  ['wince', 'waince', 0],
#  ['ladder', 'sladder', 0],
#  ['logic', 'choice', 1],
#  ['bottle', 'divide', 1],
#  ['never', 'march', 1],
#  ['transport', 'gransport', 0],
#  ['collect', 'house', 1],
#  ['vacation', 'vapation', 0],
#  ['outer', 'virus', 1],
#  ['decade', 'blanket', 1],
#  ['celebrate', 'celvebrate', 0],
#  ['aspect', 'asypect', 0],
#  ['table', 'tablwe', 0],
#  ['result', 'waste', 1],
#  ['feature', 'magic', 1],
#  ['clean', 'celan', 0],
#  ['result', 'rersult', 0],
#  ['wager', 'wageqr', 0],
#  ['candidate', 'caddate', 0],
#  ['tourist', 'community', 1],
#  ['fantastic', 'fantastig', 0],
#  ['giraffe', 'giraffae', 0],
#  ...]

# %%
df = pd.DataFrame(combined_data, columns=["Correct Word", "Incorrect Word", "Target"])

# %%
len(df)
# Out:
# 323616

# %%
df.groupby(["Target"])["Target"].count()
# Out:
# Target
# 0    196306
# 1    127310
# Name: Target, dtype: int64

# %%
print(df.groupby(["Correct Word","Target"]).count().sort_values(by=["Correct Word","Target"]))
# Out:
#                      Incorrect Word
# Correct Word Target
# abandon      0                  391
#              1                  201
# ability      0                  392
#              1                  215
# absence      0                  393
# ...                             ...
# zodiac       1                  201
# zone         0                  214
#              1                  217
# zoom         0                  211
#              1                  208
#
# [1212 rows x 1 columns]

# %%
df.to_csv("./datasets/Most Used Words Combinations New.csv",index=False)

# %%
# pd.read_csv("Custom Dict Dataset.csv")
