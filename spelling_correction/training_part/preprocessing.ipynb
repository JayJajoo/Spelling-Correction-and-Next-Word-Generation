# %%
import pandas as pd
import numpy as np
import itertools
import random

# %%
# dataset = pd.read_csv("./datasets/dict.csv")
# words = dataset["word"]
# words = list(set(words.to_numpy()))
# words = [item for item in words if isinstance(item, str) and len(item)>2]

# %%
# words = ['cattle', 'beautiful', 'input', 'daring', 'predict', 'giraffe', 'blend', 'simplify', 'knack', 'parent', 'elevate', 'incentive', 'gather', 'clumsy', 'zoom', 'aluminum', 'example', 'town', 'clerk', 'work', 'disease', 'solve', 'change', 'flavor', 'vase', 'attach', 'assemble', 'interest', 'react', 'wince', 'show', 'sensitive', 'mount', 'luck', 'wager', 'pretty', 'aspect', 'camera', 'zodiac', 'zinc', 'explore', 'mile', 'grid', 'poor', 'violent', 'absorb', 'desire', 'zero', 'charitable', 'tolerate', 'doubt', 'guitar', 'enrich', 'clamp', 'across', 'active', 'friend', 'feature', 'never', 'blanket', 'middle', 'flood', 'kitchen', 'candidate', 'cease', 'leads', 'bravery', 'rescue', 'outdoor', 'update', 'trust', 'neutral', 'mobile', 'roam', 'dance', 'bitter', 'energy', 'together', 'discover', 'couch', 'link', 'model', 'finance', 'citizen', 'horizon', 'cliff', 'ability', 'cool', 'latter', 'exhibit', 'relate', 'crisis', 'enemy', 'arrange', 'project', 'rate', 'zone', 'visit', 'combine', 'athlete', 'clock', 'hurdle', 'banker', 'brisk', 'stranger', 'buy', 'skip', 'assess', 'carbon', 'console', 'alike', 'waste', 'expect', 'emerge', 'drink', 'house', 'false', 'death', 'youth', 'rival', 'explode', 'wonder', 'heart', 'myth', 'tension', 'charm', 'expose', 'result', 'stabilize', 'synthesis', 'jumpy', 'excel', 'community', 'combat', 'error', 'bake', 'return', 'record', 'accept', 'meadow', 'create', 'bottle', 'favor', 'private', 'actor', 'demand', 'dear', 'chamber', 'warn', 'puppet', 'academy', 'collect', 'store', 'worse', 'variable', 'ride', 'human', 'excited', 'text', 'vote', 'debt', 'yearly', 'natural', 'improve', 'imagine', 'occupy', 'stuck', 'flame', 'forward', 'society', 'your', 'jump', 'mental', 'volume', 'advance', 'lacks', 'yell', 'judge', 'cage', 'hospital', 'billion', 'barrier', 'primary', 'season', 'clean', 'spirit', 'grace', 'crown', 'leader', 'court', 'winter', 'formula', 'run', 'stiff', 'shelter', 'depth', 'peach', 'resource', 'engage', 'mention', 'better', 'dangerous', 'review', 'obtain', 'noble', 'clue', 'truth', 'stare', 'attack', 'student', 'health', 'agency', 'literary', 'average', 'wish', 'action', 'accuse', 'abuse', 'yellow', 'common', 'bicycle', 'habit', 'smell', 'impress', 'quality', 'profit', 'trade', 'mild', 'clash', 'place', 'wheel', 'listen', 'fitness', 'eternal', 'order', 'fluent', 'tourist', 'picture', 'shine', 'fishing', 'social', 'stress', 'whole', 'bargain', 'bizarre', 'chill', 'survive', 'calibrate', 'biology', 'appliance', 'foolish', 'kite', 'cloud', 'nature', 'tender', 'image', 'exact', 'vacation', 'reduce', 'universe', 'amount', 'experiment', 'limit', 'humor', 'front', 'apply', 'anxiety', 'artist', 'bricks', 'post', 'belief', 'journal', 'public', 'noir', 'fantastic', 'garden', 'future', 'yoga', 'select', 'object', 'effect', 'toll', 'element', 'vary', 'diverse', 'approach', 'allege', 'navigate', 'start', 'begin', 'morning', 'choice', 'approve', 'smart', 'elate', 'airport', 'angry', 'balloon', 'single', 'justify', 'fruit', 'vast', 'further', 'become', 'support', 'school', 'mind', 'compete', 'government', 'anniversary', 'notable', 'agree', 'utility', 'essay', 'control', 'position', 'value', 'voice', 'class', 'custom', 'issue', 'mature', 'symbol', 'lemon', 'joke', 'doubtful', 'blink', 'council', 'snow', 'restore', 'edgy', 'group', 'honor', 'allergy', 'tackle', 'plane', 'piano', 'adapt', 'earth', 'damage', 'neat', 'believe', 'transport', 'allegiance', 'option', 'danger', 'test', 'cherry', 'study', 'welcome', 'reason', 'total', 'trouble', 'fact', 'commerce', 'jolly', 'vision', 'program', 'system', 'enforce', 'cheap', 'vivid', 'mansion', 'table', 'found', 'knight', 'yarn', 'aware', 'advice', 'verify', 'cancer', 'company', 'commodity', 'lives', 'impact', 'account', 'outcome', 'respect', 'mob', 'runway', 'architecture', 'careful', 'outline', 'trick', 'chance', 'silent', 'badly', 'workshop', 'address', 'affect', 'life', 'focus', 'today', 'celebrate', 'weary', 'entry', 'near', 'excuse', 'decade', 'unit', 'quote', 'allies', 'notice', 'water', 'other', 'wave', 'argue', 'clarify', 'classic', 'journey', 'calm', 'guard', 'sense', 'beyond', 'migrate', 'applause', 'beauty', 'accident', 'brother', 'alter', 'threat', 'reach', 'duty', 'bachelor', 'mice', 'brown', 'plenty', 'absence', 'union', 'price', 'roar', 'deficit', 'move', 'policy', 'joyful', 'density', 'banish', 'virus', 'river', 'taste', 'climate', 'event', 'king', 'equal', 'moment', 'target', 'cube', 'yes', 'logic', 'gesture', 'true', 'stock', 'divide', 'western', 'laugh', 'minute', 'celestial', 'rain', 'open', 'moral', 'devil', 'expand', 'mail', 'prove', 'type', 'access', 'remove', 'budget', 'peace', 'witness', 'asset', 'delicate', 'pulse', 'charter', 'point', 'inspire', 'anger', 'difference', 'grate', 'freedom', 'comet', 'station', 'current', 'juror', 'already', 'tooth', 'personal', 'outer', 'partner', 'suffer', 'ideal', 'knee', 'older', 'color', 'close', 'tempt', 'walk', 'obese', 'mourn', 'assault', 'worker', 'harsh', 'scare', 'adopt', 'ready', 'dominate', 'happen', 'absent', 'privacy', 'ignore', 'magic', 'method', 'scale', 'settle', 'host', 'fashion', 'debate', 'gender', 'tonight', 'breathe', 'guilt', 'cycle', 'moat', 'vibe', 'teeth', 'unite', 'against', 'analysis', 'chicken', 'bother', 'mask', 'global', 'trend', 'analyze', 'nail', 'provoke', 'cabin', 'assistant', 'unique', 'rosy', 'slope', 'street', 'ancient', 'abandon', 'step', 'sick', 'deal', 'yesterday', 'array', 'march', 'defend', 'dungeon', 'pattern', 'round', 'majority', 'motel', 'smooth', 'adult', 'appeal', 'sound', 'bring', 'recall', 'ladder', 'culture', 'design', 'news', 'dialogue', 'oxygen', 'alert', 'almost', 'torch', 'whisper', 'hike', 'separate', 'learn', 'market', 'label', 'catch', 'final', 'dreamer', 'handle', 'buyer', 'brief', 'forecast', 'cousin', 'acquire', 'second', 'query', 'agile', 'knock', 'power', 'advantage', 'fine', 'lender', 'pet', 'capture', 'orange', 'planet', 'june', 'fetch', 'flock', 'zebra', 'brand', 'occasions', 'team', 'kiss']
words = np.load("./datasets/text_unique_tokens.npy",allow_pickle=True)
len(words)
# Out:
# 8001

# %%
words = list(words)

# %%
def generate_all_misspellings(word):
    word = str(word)
    if len(word) < 2:
        return [word]  
    
    word = list(word)
    possible_misspellings = set()
    
    for indices in itertools.combinations(range(len(word)), 2):
        word_copy = word[:]
        
        # Swap
        swapped = word_copy[:]
        swapped[indices[0]], swapped[indices[1]] = swapped[indices[1]], swapped[indices[0]]
        possible_misspellings.add("".join(swapped))
        
        # Replace
        for i in indices:
            for char in "abcdefghijklmnopqrstuvwxyz":
                replaced = word_copy[:]
                replaced[i] = char
                possible_misspellings.add("".join(replaced))
        
        # Delete
        deleted = word_copy[:]
        for i in sorted(indices, reverse=True):
            del deleted[i]
        possible_misspellings.add("".join(deleted))
        
        # Insert
        for i in indices:
            for char in "abcdefghijklmnopqrstuvwxyz":
                inserted = word_copy[:]
                inserted.insert(i, char)
                possible_misspellings.add("".join(inserted))
    
    return list(possible_misspellings)

# %%
data = [[word, misspelling, 0] for word in words for misspelling in generate_all_misspellings(word)]
# half_size = len(data) // 2
# data = random.sample(data, half_size)

# %%
def generate_totally_incorrect_pairs(words, num_pairs_min=300, num_pairs_max=400):
    different_words = []
    for idx, word in enumerate(words):
        other_words = words[:idx] + words[idx+1:]  
        num_pairs = random.randint(num_pairs_min, num_pairs_max)
        random_250_words = random.sample(other_words, num_pairs)
        for other_word in random_250_words:
            different_words.append([word, other_word, 1])
    return different_words

# %%
totally_different_words = generate_totally_incorrect_pairs(words)

# %%
combined_data = totally_different_words + data
random.shuffle(combined_data)
combined_data
# Out:
# [['safer', 'safxr', 0],
#  ['admirably', 'whip', 1],
#  ['differently', 'drfferently', 0],
#  ['disregarded', 'pew', 1],
#  ['appropriate', 'william', 1],
#  ['california', 'califorsia', 0],
#  ['fraud', 'plentiful', 1],
#  ['sticking', 'shouting', 1],
#  ['loomed', 'loodmed', 0],
#  ['characterises', 'hushing', 1],
#  ['cold', 'division', 1],
#  ['tags', 'seat', 1],
#  ['begins', 'patches', 1],
#  ['concluding', 'depends', 1],
#  ['incisive', 'iyncisive', 0],
#  ['community', 'coimunity', 0],
#  ['announcement', 'snnouncement', 0],
#  ['uncourteous', 'uyncourteous', 0],
#  ['reference', 'tops', 1],
#  ['cloth', 'closh', 0],
#  ['gullet', 'gulllt', 0],
#  ['reigning', 'reqigning', 0],
#  ['baxter', 'waxter', 0],
#  ['rascally', 'scally', 0],
#  ['orders', 'enters', 1],
#  ['boys', 'wriggled', 1],
#  ['breakfasts', 'breakfpasts', 0],
#  ['god', 'plaid', 1],
#  ['agitation', 'agitatiown', 0],
#  ['interested', 'intensified', 1],
#  ['slurring', 'slurrwng', 0],
#  ['outweigh', 'outweigjh', 0],
#  ['human', 'humean', 0],
#  ['pity', 'nonentity', 1],
#  ['sailing', 'sadling', 0],
#  ['tout', 'clearer', 1],
#  ['tell', 'teyll', 0],
#  ['long', 'motives', 1],
#  ['pondicherry', 'lit', 1],
#  ['understood', 'unserdtood', 0],
#  ['brewer', 'gathered', 1],
#  ['hopkins', 'hopkeins', 0],
#  ['conjunction', 'cdnjunction', 0],
#  ['aquiline', 'minute', 1],
#  ['death', 'sable', 1],
#  ['claspings', 'clayspings', 0],
#  ['human', 'amiable', 1],
#  ['barber', 'judged', 1],
#  ['duchess', 'dguchess', 0],
#  ['origin', 'globe', 1],
#  ['existence', 'xstence', 0],
#  ['poor', 'disease', 1],
#  ['bit', 'freed', 1],
#  ['assisting', 'blurs', 1],
#  ['spouting', 'hand', 1],
#  ['heaped', 'shiver', 1],
#  ['unprofitable', 'unpnrofitable', 0],
#  ['shortly', 'instruction', 1],
#  ['observing', 'these', 1],
#  ['steaming', 'steamidg', 0],
#  ['bricks', 'bfricks', 0],
#  ['fagged', 'faggesd', 0],
#  ['bicycling', 'inflamed', 1],
#  ['headgear', 'heamdgear', 0],
#  ['college', 'hidden', 1],
#  ['obey', 'strengthen', 1],
#  ['posterior', 'pserior', 0],
#  ['expectancy', 'expbctancy', 0],
#  ['squeezed', 'squeeged', 0],
#  ['records', 'jerkily', 1],
#  ['astonishment', 'fidelity', 1],
#  ['hence', 'hejce', 0],
#  ['broke', 'jroke', 0],
#  ['grasping', 'data', 1],
#  ['chaffering', 'chaffrig', 0],
#  ['waited', 'waitezd', 0],
#  ['noiselessly', 'noisejlessly', 0],
#  ['fixed', 'fixec', 0],
#  ['talking', 'tralking', 0],
#  ['cornwall', 'cornwaljl', 0],
#  ['discoloured', 'protestation', 1],
#  ['manifestations', 'manifestationn', 0],
#  ['attitude', 'attituse', 0],
#  ['dearest', 'villagers', 1],
#  ['guard', 'guagrd', 0],
#  ['stabbed', 'stabnbed', 0],
#  ['failing', 'railing', 0],
#  ['waterproof', 'waterprofo', 0],
#  ['ships', 'bowing', 1],
#  ['lovely', 'broadened', 1],
#  ['originality', 'oriminality', 0],
#  ['firelight', 'struck', 1],
#  ['banks', 'goodwins', 1],
#  ['live', 'flurried', 1],
#  ['stepdaughter', 'stepxdaughter', 0],
#  ['dearest', 'deaoest', 0],
#  ['newsletter', 'nsletter', 0],
#  ['arnsworth', 'arnswyrth', 0],
#  ['oscillated', 'oscilulated', 0],
#  ['discretion', 'harm', 1],
#  ['spectacle', 'lpectacle', 0],
#  ['refinement', 'wrefinement', 0],
#  ['infringement', 'venomous', 1],
#  ['pull', 'tropics', 1],
#  ['chaffed', 'cheffed', 0],
#  ['speaks', 'gap', 1],
#  ['groan', 'develop', 1],
#  ['kissed', 'episodes', 1],
#  ['mistaken', 'mistakeun', 0],
#  ['crusted', 'ciusted', 0],
#  ['passages', 'dassages', 0],
#  ['vehicle', 'vkhicle', 0],
#  ['breaking', 'such', 1],
#  ['bohemian', 'bohemitan', 0],
#  ['disappoint', 'dishappoint', 0],
#  ['forecastle', 'fotecastle', 0],
#  ['calves', 'suits', 1],
#  ['discontinue', 'typewriter', 1],
#  ['abjure', 'fuller', 1],
#  ['glare', 'warmed', 1],
#  ['bang', 'bsang', 0],
#  ['lustre', 'oustre', 0],
#  ['status', 'fantastic', 1],
#  ['scorn', 'appeals', 1],
#  ['dissatisfied', 'pissatisfied', 0],
#  ['london', 'xlondon', 0],
#  ['frosty', 'frostmy', 0],
#  ['tested', 'tosted', 0],
#  ['creaking', 'suffering', 1],
#  ['occasional', 'lccasional', 0],
#  ['exporting', 'easterly', 1],
#  ['power', 'poywer', 0],
#  ['upper', 'arthur', 1],
#  ['barrow', 'top', 1],
#  ['representative', 'reprisentative', 0],
#  ['crawled', 'screamed', 1],
#  ['dread', 'dzead', 0],
#  ['ein', 'eiz', 0],
#  ['started', 'international', 1],
#  ['collapsed', 'wollapsed', 0],
#  ['flickering', 'flicjering', 0],
#  ['general', 'generhl', 0],
#  ['sussex', 'suxssex', 0],
#  ['sport', 'sptrt', 0],
#  ['anyhow', 'ayhw', 0],
#  ['enthusiastic', 'enthusiustic', 0],
#  ['mangled', 'mangeld', 0],
#  ['announcement', 'also', 1],
#  ['annoyance', 'annoyce', 0],
#  ['particulars', 'parlticulars', 0],
#  ['endeavour', 'endeavtour', 0],
#  ['fleet', 'fee', 0],
#  ['wonderful', 'pockets', 1],
#  ['entrance', 'majesty', 1],
#  ['degree', 'ndegree', 0],
#  ['stile', 'jewels', 1],
#  ['accompli', 'accomjpli', 0],
#  ['correspondence', 'correspondencf', 0],
#  ['online', 'outr', 1],
#  ['apology', 'hesitate', 1],
#  ['shots', 'wshots', 0],
#  ['turf', 'tudf', 0],
#  ['completely', 'completwely', 0],
#  ['revealed', 'rfevealed', 0],
#  ['outward', 'outwacd', 0],
#  ['bye', 'lap', 1],
#  ['mottled', 'motthed', 0],
#  ['altered', 'widespread', 1],
#  ['lent', 'composer', 1],
#  ['fare', 'farte', 0],
#  ['affections', 'aofections', 0],
#  ['notable', 'banged', 1],
#  ['hear', 'aberdeen', 1],
#  ['whatever', 'whatevjr', 0],
#  ['victoria', 'settling', 1],
#  ['emptied', 'shiver', 1],
#  ['introspective', 'intrdspective', 0],
#  ['nobleman', 'harrow', 1],
#  ['communicative', 'communicativg', 0],
#  ['hunted', 'frowning', 1],
#  ['flurried', 'flurriei', 0],
#  ['acquiesce', 'successfully', 1],
#  ['abomination', 'abromination', 0],
#  ['forts', 'elect', 1],
#  ['arrest', 'showed', 1],
#  ['tune', 'mtune', 0],
#  ['gloss', 'society', 1],
#  ['shiny', 'dweller', 1],
#  ['catching', 'dcatching', 0],
#  ['org', 'lorg', 0],
#  ['barber', 'barbemr', 0],
#  ['grasp', 'gilt', 1],
#  ['actionable', 'actionabze', 0],
#  ['forestalling', 'undo', 1],
#  ['selfish', 'seolfish', 0],
#  ['anything', 'nythng', 0],
#  ['works', 'trite', 1],
#  ['stark', 'sctark', 0],
#  ['heaving', 'heavinw', 0],
#  ['modest', 'jose', 1],
#  ['biographies', 'biograhes', 0],
#  ['february', 'februlry', 0],
#  ['entreated', 'entreateu', 0],
#  ['sailor', 'festivities', 1],
#  ['maker', 'southerton', 1],
#  ['heels', 'hhels', 0],
#  ['smear', 'fugitives', 1],
#  ['retort', 'retert', 0],
#  ['prepared', 'travelling', 1],
#  ['mingled', 'restrictions', 1],
#  ['heated', 'hetd', 0],
#  ['passenger', 'administration', 1],
#  ['candid', 'capndid', 0],
#  ['accomplished', 'believe', 1],
#  ['risers', 'great', 1],
#  ['luggage', 'luhgage', 0],
#  ['placed', 'dangerous', 1],
#  ['ferocious', 'ferociolus', 0],
#  ['meaning', 'reaning', 0],
#  ['figures', 'figdres', 0],
#  ['willingly', 'charm', 1],
#  ['attractions', 'attramctions', 0],
#  ['enables', 'enablves', 0],
#  ['political', 'powitical', 0],
#  ['necessarily', 'those', 1],
#  ['financier', 'finatncier', 0],
#  ['tangible', 'measure', 1],
#  ['intricate', 'intricatce', 0],
#  ['workmen', 'pauper', 1],
#  ['whined', 'wrists', 1],
#  ['extremely', 'salt', 1],
#  ['difficulties', 'diffvculties', 0],
#  ['saturday', 'suturday', 0],
#  ['struggle', 'strugglv', 0],
#  ['theories', 'symptom', 1],
#  ['slit', 'nonsense', 1],
#  ['contemplative', 'ontemplativ', 0],
#  ['sob', 'deeper', 1],
#  ['gong', 'hong', 0],
#  ['delicacy', 'delvicacy', 0],
#  ['amazement', 'recovered', 1],
#  ['monica', 'fallen', 1],
#  ['testament', 'recoil', 1],
#  ['ignorance', 'ignvorance', 0],
#  ['painful', 'murmured', 1],
#  ['bulldog', 'buxldog', 0],
#  ['leaned', 'lekaned', 0],
#  ['iota', 'expedition', 1],
#  ['turned', 'finding', 1],
#  ['untimely', 'untively', 0],
#  ['resistance', 'riesistance', 0],
#  ['gasfitters', 'gaspitters', 0],
#  ['scandals', 'scafndals', 0],
#  ['alert', 'akert', 0],
#  ['school', 'richer', 1],
#  ['freckled', 'frecbkled', 0],
#  ['triangular', 'jerked', 1],
#  ['vestas', 'vestaxs', 0],
#  ['detailed', 'confusion', 1],
#  ['beyond', 'beyovd', 0],
#  ['earrings', 'earwings', 0],
#  ['frogged', 'farogged', 0],
#  ['combine', 'permanent', 1],
#  ['mentioned', 'wind', 1],
#  ['treatment', 'permission', 1],
#  ['capable', 'campable', 0],
#  ['simon', 'ysimon', 0],
#  ['embankment', 'emibankment', 0],
#  ['peeping', 'yellow', 1],
#  ['faster', 'eccentricity', 1],
#  ['unravelled', 'unravelnled', 0],
#  ['throbbing', 'throbginb', 0],
#  ['stealthily', 'stealyhilt', 0],
#  ['infinite', 'infnie', 0],
#  ['propagation', 'pnopagation', 0],
#  ['tangible', 'intimate', 1],
#  ['bohemia', 'creature', 1],
#  ['railed', 'despaired', 1],
#  ['favoured', 'favoqred', 0],
#  ['lane', 'story', 1],
#  ['news', 'newos', 0],
#  ['expectancies', 'expectanwcies', 0],
#  ['enters', 'onters', 0],
#  ['everywhere', 'everyqwhere', 0],
#  ['frightened', 'parallel', 1],
#  ['sprung', 'sprunn', 0],
#  ['display', 'dinsplay', 0],
#  ['fetch', 'depends', 1],
#  ['tiniest', 'curtain', 1],
#  ['crown', 'crowdn', 0],
#  ['deceased', 'gracious', 1],
#  ['foul', 'regain', 1],
#  ['heaving', 'hkaving', 0],
#  ['delight', 'dfelight', 0],
#  ['stroll', 'rabbit', 1],
#  ['dangerously', 'stepping', 1],
#  ['likely', 'cleared', 1],
#  ['tin', 'trace', 1],
#  ['reconsider', 'rbconsider', 0],
#  ['where', 'whure', 0],
#  ['tired', 'ttred', 0],
#  ['grotesque', 'labour', 1],
#  ['own', 'nwo', 0],
#  ['exhibited', 'exhibitfed', 0],
#  ['jove', 'personality', 1],
#  ['feigned', 'disguise', 1],
#  ['young', 'younz', 0],
#  ['production', 'produution', 0],
#  ['importers', 'imporlers', 0],
#  ['loitering', 'loetering', 0],
#  ['kensington', 'kensingtoen', 0],
#  ['foppishness', 'social', 1],
#  ['secretary', 'foliage', 1],
#  ['approached', 'combination', 1],
#  ['pacific', 'humdrum', 1],
#  ['personate', 'peosrnate', 0],
#  ['briony', 'anderson', 1],
#  ['silhouette', 'anxious', 1],
#  ['texas', 'cudgelled', 1],
#  ['obligations', 'advised', 1],
#  ['freckled', 'freckletd', 0],
#  ['dummy', 'udmmy', 0],
#  ['sound', 'sounk', 0],
#  ['painfully', 'yainfully', 0],
#  ['edgeware', 'volume', 1],
#  ['crowns', 'climbing', 1],
#  ['embankment', 'prove', 1],
#  ['federal', 'tottering', 1],
#  ['tug', 'akin', 1],
#  ['irresistible', 'irresistiblx', 0],
#  ['joint', 'unacquainted', 1],
#  ['blend', 'tiny', 1],
#  ['speaking', 'dipping', 1],
#  ['fleecy', 'marrying', 1],
#  ['understood', 'understootd', 0],
#  ['loose', 'loyse', 0],
#  ['sensational', 'dependent', 1],
#  ['lenient', 'screamed', 1],
#  ['trifles', 'womanly', 1],
#  ['refined', 'refiend', 0],
#  ['consult', 'consuclt', 0],
#  ['peasant', 'peasankt', 0],
#  ['tailless', 'taiplless', 0],
#  ['purity', 'tax', 1],
#  ['december', 'decembeb', 0],
#  ['contains', 'containg', 0],
#  ['breadth', 'upset', 1],
#  ['cripple', 'waited', 1],
#  ['berkshire', 'crowns', 1],
#  ['magnificent', 'smallest', 1],
#  ['promotion', 'pronmotion', 0],
#  ['coming', 'comling', 0],
#  ['rule', 'lovely', 1],
#  ['slurring', 'preserves', 1],
#  ['cultured', 'greyish', 1],
#  ['compromised', 'compromished', 0],
#  ['lawyer', 'wrote', 1],
#  ['rifle', 'rpfle', 0],
#  ['tattered', 'attred', 0],
#  ['oil', 'oiq', 0],
#  ['blandly', 'gaped', 1],
#  ['plumped', 'pmumped', 0],
#  ['revolved', 'orphan', 1],
#  ['pal', 'mal', 0],
#  ['glanced', 'glancepd', 0],
#  ['examination', 'scuffle', 1],
#  ['necessity', 'necessibty', 0],
#  ['shrieked', 'tallow', 1],
#  ['survived', 'surveved', 0],
#  ['manager', 'yards', 1],
#  ['quivering', 'nine', 1],
#  ['cosmopolitan', 'wandered', 1],
#  ['superior', 'superiwor', 0],
#  ['crushing', 'final', 1],
#  ['asleep', 'helper', 1],
#  ['overcome', 'overcooe', 0],
#  ['seaports', 'seapkorts', 0],
#  ['untamed', 'untammd', 0],
#  ['help', 'entering', 1],
#  ['grating', 'trivial', 1],
#  ['montana', 'employed', 1],
#  ['changing', 'walked', 1],
#  ['dismantled', 'dismanktled', 0],
#  ['ribbed', 'ribbtd', 0],
#  ['examined', 'farintosh', 1],
#  ['plumped', 'plumpex', 0],
#  ['depositors', 'depvsitors', 0],
#  ['interruption', 'intexruption', 0],
#  ['beg', 'perpetrators', 1],
#  ['searching', 'searchinkg', 0],
#  ['confess', 'hazarded', 1],
#  ['kensington', 'kensingtosn', 0],
#  ['triangular', 'trganiular', 0],
#  ['expressions', 'exprejssions', 0],
#  ['midway', 'mud', 1],
#  ['leading', 'cracked', 1],
#  ['ingenious', 'inwenious', 0],
#  ['guardianship', 'guardiasship', 0],
#  ['dropping', 'dpping', 0],
#  ['relapsed', 'relapqsed', 0],
#  ['campaign', 'calpaign', 0],
#  ['complexion', 'complnxion', 0],
#  ['intimacy', 'footmarks', 1],
#  ['ashen', 'vain', 1],
#  ['liberated', 'room', 1],
#  ['singular', 'violates', 1],
#  ['hoping', 'phoping', 0],
#  ['sobbed', 'sabbed', 0],
#  ['neville', 'nevilhle', 0],
#  ['capture', 'ucapture', 0],
#  ['fatigued', 'fatiyued', 0],
#  ['smoothness', 'somothness', 0],
#  ['method', 'thames', 1],
#  ['sharp', 'blotted', 1],
#  ['track', 'readily', 1],
#  ['candidate', 'cajdidate', 0],
#  ['pointing', 'pninting', 0],
#  ['tells', 'uncovered', 1],
#  ['realising', 'ealisin', 0],
#  ['about', 'heartily', 1],
#  ['impending', 'impendibg', 0],
#  ['nosed', 'noced', 0],
#  ['corresponded', 'possessed', 1],
#  ['trunk', 'curious', 1],
#  ['kitchen', 'kjitchen', 0],
#  ['announced', 'annnounced', 0],
#  ['frame', 'oxford', 1],
#  ['reaching', 'criminal', 1],
#  ['servitude', 'servitxude', 0],
#  ['expecting', 'exsecting', 0],
#  ['outstanding', 'tutstanding', 0],
#  ['clear', 'cleaw', 0],
#  ['blinds', 'blindbs', 0],
#  ['ones', 'divined', 1],
#  ['carlo', 'tattooed', 1],
#  ['uncourteous', 'uwcourteous', 0],
#  ['eventually', 'develop', 1],
#  ['mixture', 'maxture', 0],
#  ['tossed', 'tossged', 0],
#  ['threw', 'tzrew', 0],
#  ['julia', 'winchester', 1],
#  ['impatience', 'impatienuce', 0],
#  ['tops', 'assembled', 1],
#  ['rejoin', 'deserting', 1],
#  ['recalled', 'thrust', 1],
#  ['bears', 'sholto', 1],
#  ['visible', 'isn', 1],
#  ['although', 'athoug', 0],
#  ['belongs', 'belongu', 0],
#  ['mills', 'hills', 0],
#  ['scared', 'speaking', 1],
#  ['mention', 'plot', 1],
#  ['invested', 'enters', 1],
#  ['medium', 'heap', 1],
#  ['forgive', 'fodrgive', 0],
#  ['westphail', 'flatter', 1],
#  ['meet', 'purses', 1],
#  ['compunction', 'cocpunction', 0],
#  ['computers', 'keys', 1],
#  ['undid', 'hndid', 0],
#  ['alluded', 'flushed', 1],
#  ['following', 'fbollowing', 0],
#  ['blot', 'tlob', 0],
#  ['knowledge', 'screamed', 1],
#  ['resolve', 'sluggishly', 1],
#  ['disadvantage', 'disadvaniage', 0],
#  ['emptied', 'buildings', 1],
#  ['bandaged', 'bundaged', 0],
#  ['severely', 'unfailingly', 1],
#  ['break', 'reach', 1],
#  ['glowing', 'glowqng', 0],
#  ['sunlight', 'stupidity', 1],
#  ['tomfoolery', 'softly', 1],
#  ['arrest', 'arbest', 0],
#  ['sign', 'qign', 0],
#  ['restraint', 'westraint', 0],
#  ['hungry', 'litter', 1],
#  ['self', 'dress', 1],
#  ['beautifully', 'bmeautifully', 0],
#  ['blush', 'supposition', 1],
#  ['franco', 'old', 1],
#  ['kill', 'il', 0],
#  ['wronged', 'cwronged', 0],
#  ['compensated', 'stagnant', 1],
#  ['question', 'straighten', 1],
#  ['registers', 'regispers', 0],
#  ['betraying', 'housekeeper', 1],
#  ['hollowed', 'changed', 1],
#  ['burnwell', 'inferred', 1],
#  ['advice', 'advice', 0],
#  ['ballarat', 'conditions', 1],
#  ['jephro', 'curving', 1],
#  ['defiantly', 'defiantlk', 0],
#  ['backwater', 'nod', 1],
#  ['concealed', 'retorted', 1],
#  ['introducing', 'handcuffs', 1],
#  ['fireplace', 'firepblace', 0],
#  ['gaze', 'laughing', 1],
#  ['rested', 'vile', 1],
#  ['expressly', 'expressrly', 0],
#  ['sky', 'bunch', 1],
#  ['collected', 'seaman', 1],
#  ['convenience', 'waved', 1],
#  ['kings', 'momentary', 1],
#  ['screaming', 'zscreaming', 0],
#  ['observed', 'obsgrved', 0],
#  ['redder', 'nedder', 0],
#  ['scuffle', 'scufdfle', 0],
#  ['moral', 'moiral', 0],
#  ['pancras', 'dangling', 1],
#  ['photograph', 'photolgraph', 0],
#  ['docks', 'horsham', 1],
#  ['generally', 'generallm', 0],
#  ['mansion', 'quarrels', 1],
#  ['accompanied', 'accompaqied', 0],
#  ['built', 'foreman', 1],
#  ['consciousness', 'conwsciousness', 0],
#  ['payment', 'pgayment', 0],
#  ['card', 'smile', 1],
#  ['fluffy', 'madly', 1],
#  ['argument', 'argukent', 0],
#  ['significant', 'sigpnificant', 0],
#  ['jerkily', 'yourselves', 1],
#  ['securer', 'serurec', 0],
#  ['arrows', 'arpows', 0],
#  ['mantelpiece', 'between', 1],
#  ['southerton', 'souvtherton', 0],
#  ['nerves', 'simon', 1],
#  ['expired', 'flashing', 1],
#  ['manageress', 'managerexs', 0],
#  ['hatherley', 'hatwherley', 0],
#  ['laurel', 'threatens', 1],
#  ['chestnut', 'chestnmut', 0],
#  ['problems', 'problees', 0],
#  ['excuses', 'jump', 1],
#  ['temporary', 'tempoarary', 0],
#  ['stables', 'statbles', 0],
#  ['gales', 'gages', 0],
#  ['codes', 'sovereigns', 1],
#  ['riverside', 'rirside', 0],
#  ['sucked', 'determined', 1],
#  ['clergyman', 'thin', 1],
#  ['doings', 'doingys', 0],
#  ['warmly', 'wamrly', 0],
#  ['sorry', 'happen', 1],
#  ['lothman', 'clothman', 0],
#  ['dusty', 'dugty', 0],
#  ['probable', 'provable', 0],
#  ['baggy', 'bgggy', 0],
#  ['intrigue', 'attack', 1],
#  ['eligible', 'eligtble', 0],
#  ['pure', 'puje', 0],
#  ['nonconformist', 'costs', 1],
#  ['performing', 'perfzorming', 0],
#  ['tracks', 'sadly', 1],
#  ['career', 'tomfoolery', 1],
#  ['plausible', 'plausiblpe', 0],
#  ['depressing', 'dekpressing', 0],
#  ['neighbouring', 'neighbohuring', 0],
#  ['cocking', 'cockvng', 0],
#  ['internal', 'niternal', 0],
#  ['positive', 'positisve', 0],
#  ['fourteenth', 'qourteenth', 0],
#  ['cabby', 'cabgby', 0],
#  ['frill', 'technical', 1],
#  ['matches', 'northumberland', 1],
#  ['writings', 'writtngs', 0],
#  ['mendicants', 'butted', 1],
#  ['outward', 'ouard', 0],
#  ['ending', 'equinoctial', 1],
#  ['reigning', 'skylight', 1],
#  ['carved', 'foresee', 1],
#  ['forceps', 'iorceps', 0],
#  ['different', 'dpifferent', 0],
#  ['topic', 'beeches', 1],
#  ['get', 'vacuous', 1],
#  ['tea', 'tep', 0],
#  ['occurrence', 'gratefully', 1],
#  ['consciousness', 'baggy', 1],
#  ['matters', 'distinct', 1],
#  ['anxiously', 'anxiouslky', 0],
#  ['feed', 'fees', 0],
#  ['contemplative', 'contempqative', 0],
#  ['beam', 'conceive', 1],
#  ['harmless', 'kharmless', 0],
#  ['equally', 'equayll', 0],
#  ['magistrates', 'mavgistrates', 0],
#  ['working', 'dared', 1],
#  ['brilliantly', 'brglliantly', 0],
#  ['cried', 'restored', 1],
#  ['hesitation', 'hesitatidon', 0],
#  ['masses', 'massse', 0],
#  ['defeated', 'aefedted', 0],
#  ['ballarat', 'outskirts', 1],
#  ['lazily', 'lapzily', 0],
#  ['slits', 'reverse', 1],
#  ['savannah', 'stvannah', 0],
#  ['anoints', 'featureless', 1],
#  ['charming', 'chgrmina', 0],
#  ['leakage', 'visits', 1],
#  ['looming', 'lofoming', 0],
#  ['traces', 'traoes', 0],
#  ['believed', 'jelieved', 0],
#  ['peculiarities', 'teculiarities', 0],
#  ['limping', 'limpbng', 0],
#  ['snuffbox', 'snlffbox', 0],
#  ['vanished', 'consequential', 1],
#  ['palpitating', 'palpitatuing', 0],
#  ['feet', 'palm', 1],
#  ['inadequate', 'egria', 1],
#  ['sold', 'question', 1],
#  ['commissionaire', 'commissionaiyre', 0],
#  ['resort', 'natured', 1],
#  ['chamber', 'ceamber', 0],
#  ['positive', 'posvitive', 0],
#  ['shows', 'shews', 0],
#  ['chatting', 'insufficient', 1],
#  ['boarding', 'represented', 1],
#  ['amusing', 'amusxing', 0],
#  ['grinned', 'thicket', 1],
#  ['wander', 'wanoer', 0],
#  ['maggie', 'maggxie', 0],
#  ['aldershot', 'alderyshot', 0],
#  ['resolute', 'rxsolute', 0],
#  ['feeble', 'precautions', 1],
#  ['statements', 'stpatements', 0],
#  ['magistrate', 'magistrite', 0],
#  ['caressing', 'postmarks', 1],
#  ['element', 'ement', 0],
#  ['vehemence', 'vehemrence', 0],
#  ['licensed', 'seldom', 1],
#  ['ordnance', 'oridnance', 0],
#  ['hours', 'honurs', 0],
#  ['dweller', 'steam', 1],
#  ['ugly', 'hugly', 0],
#  ['derived', 'single', 1],
#  ['celebrated', 'celexbrated', 0],
#  ['statement', 'ystatement', 0],
#  ['greatcoat', 'oreatcoat', 0],
#  ['obstacle', 'obstacye', 0],
#  ['lamps', 'shillings', 1],
#  ['cleared', 'paternal', 1],
#  ['speckles', 'specoles', 0],
#  ['planking', 'plankong', 0],
#  ['handwriting', 'hhandwriting', 0],
#  ['don', 'lad', 1],
#  ['tiny', 'txny', 0],
#  ['lays', 'observation', 1],
#  ['wallenstein', 'walwenstein', 0],
#  ['three', 'immediately', 1],
#  ['snuff', 'synuff', 0],
#  ['studying', 'sgudyint', 0],
#  ['during', 'itself', 1],
#  ['eaten', 'vaten', 0],
#  ['imbecility', 'imbecuility', 0],
#  ['cargo', 'carigo', 0],
#  ['reverse', 'loosed', 1],
#  ['instincts', 'inst', 1],
#  ['clothes', 'fresh', 1],
#  ['footing', 'foeoting', 0],
#  ['prepared', 'pvrepared', 0],
#  ['customer', 'cutomr', 0],
#  ['struggling', 'strugglisg', 0],
#  ['gleam', 'pressure', 1],
#  ['purchasing', 'abuse', 1],
#  ['finns', 'finis', 0],
#  ['inst', 'ingt', 0],
#  ['foie', 'foip', 0],
#  ['hayling', 'pal', 1],
#  ['grain', 'newcomers', 1],
#  ['disappointed', 'hound', 1],
#  ['basis', 'trouser', 1],
#  ['stile', 'stige', 0],
#  ['supposition', 'bequest', 1],
#  ['leads', 'beef', 1],
#  ['wearisome', 'vital', 1],
#  ['cinder', 'cindger', 0],
#  ['disappearance', 'disappecarance', 0],
#  ['spare', 'talker', 1],
#  ['strain', 'sake', 1],
#  ['midway', 'unconscious', 1],
#  ['glint', 'fulfilled', 1],
#  ['jem', 'jsm', 0],
#  ['denial', 'picture', 1],
#  ['good', 'ngood', 0],
#  ['uncongenial', 'uncongencal', 0],
#  ['aproned', 'caution', 1],
#  ['threaten', 'settled', 1],
#  ['ejaculation', 'wardrobe', 1],
#  ['hebrew', 'filling', 1],
#  ['dead', 'vulnerable', 1],
#  ['continues', 'accidents', 1],
#  ['spinster', 'queen', 1],
#  ['await', 'balzac', 1],
#  ['lit', 'liet', 0],
#  ['dispose', 'dispoqse', 0],
#  ['hoarse', 'hokarse', 0],
#  ['settling', 'crewe', 1],
#  ['refrain', 'wefrain', 0],
#  ['impossible', 'afraid', 1],
#  ['extraordinary', 'extraordninary', 0],
#  ['investment', 'invelstment', 0],
#  ['bleeding', 'bleediqg', 0],
#  ['pool', 'slow', 1],
#  ['depression', 'puffing', 1],
#  ['speedily', 'speeqily', 0],
#  ['amply', 'creatures', 1],
#  ['grotesque', 'groteslue', 0],
#  ['feelings', 'falling', 1],
#  ['results', 'resulxts', 0],
#  ['carelessly', 'celessly', 0],
#  ['begin', 'bgn', 0],
#  ['poorer', 'poarer', 0],
#  ['rending', 'fending', 0],
#  ['skin', 'foreseen', 1],
#  ['whittington', 'whittingtou', 0],
#  ['bad', 'shades', 1],
#  ['heinous', 'heinous', 0],
#  ['bullet', 'intimate', 1],
#  ['house', 'houase', 0],
#  ['encompass', 'saved', 1],
#  ['relaxed', 'ushered', 1],
#  ['passenger', 'passengec', 0],
#  ['staining', 'stainfng', 0],
#  ['cigarette', 'cigadrette', 0],
#  ['pausing', 'swain', 1],
#  ['permission', 'residing', 1],
#  ['cleared', 'michael', 1],
#  ['inform', 'infowrm', 0],
#  ['programme', 'abiding', 1],
#  ['downward', 'bownward', 0],
#  ['frenchman', 'frdenchman', 0],
#  ['clenched', 'clenchead', 0],
#  ['interview', 'orphanage', 1],
#  ['beer', 'poultry', 1],
#  ['unprofitable', 'unprtfioable', 0],
#  ['elbow', 'elbou', 0],
#  ['strand', 'stramd', 0],
#  ['dream', 'yream', 0],
#  ['deceptive', 'dceptve', 0],
#  ['inheritance', 'wilton', 1],
#  ['beings', 'beinge', 0],
#  ['faded', 'flooring', 1],
#  ['valet', 'rascally', 1],
#  ['oxfordshire', 'unenforceability', 1],
#  ['scandals', 'baboon', 1],
#  ['confidential', 'confidetal', 0],
#  ['although', 'altqough', 0],
#  ['prolonged', 'urolonged', 0],
#  ['gratefully', 'holder', 1],
#  ['player', 'noiseless', 1],
#  ['carries', 'carjies', 0],
#  ['unopened', 'ynopened', 0],
#  ['fingers', 'fingeprs', 0],
#  ['winced', 'wisnced', 0],
#  ['lucy', 'exacted', 1],
#  ['comfortable', 'ascended', 1],
#  ['mentioned', 'menitoned', 0],
#  ['sentimental', 'prints', 1],
#  ['smudge', 'smupdge', 0],
#  ['foliage', 'foliarge', 0],
#  ['paddington', 'volcanic', 1],
#  ['motives', 'motiqves', 0],
#  ['writes', 'writej', 0],
#  ['winchester', 'winchese', 0],
#  ['landing', 'lbnding', 0],
#  ['whence', 'wheance', 0],
#  ['difficulty', 'dkifficulty', 0],
#  ['guide', 'odessa', 1],
#  ['baggy', 'midnight', 1],
#  ['moral', 'terror', 1],
#  ['referred', 'referroed', 0],
#  ['imitated', 'largest', 1],
#  ['transcription', 'swordsman', 1],
#  ['masculine', 'masculnine', 0],
#  ['convulsed', 'convulesd', 0],
#  ['keys', 'keygs', 0],
#  ['examine', 'examitne', 0],
#  ['pretty', 'pjretty', 0],
#  ['dog', 'squat', 1],
#  ['speckled', 'philanthropist', 1],
#  ['bag', 'bcag', 0],
#  ['slink', 'slaink', 0],
#  ['used', 'seldom', 1],
#  ['dropped', 'ran', 1],
#  ['grandfather', 'premature', 1],
#  ['western', 'westeern', 0],
#  ['pity', 'backward', 1],
#  ['commonly', 'arc', 1],
#  ['dealing', 'surmise', 1],
#  ['topic', 'topimc', 0],
#  ['glints', 'glisnts', 0],
#  ['imposed', 'starving', 1],
#  ['wine', 'emigrant', 1],
#  ['remonstrance', 'simpler', 1],
#  ['cousins', 'daubing', 1],
#  ['looking', 'hook', 1],
#  ['deserted', 'deserfted', 0],
#  ['cook', 'ycook', 0],
#  ['engagement', 'engagemxnt', 0],
#  ['attics', 'these', 1],
#  ['acquired', 'bacquired', 0],
#  ['abruptly', 'abryptly', 0],
#  ['condemned', 'condemnid', 0],
#  ['questionable', 'concise', 1],
#  ['improved', 'improzved', 0],
#  ['accompany', 'accopmany', 0],
#  ['absurd', 'contained', 1],
#  ['hurried', 'hurrided', 0],
#  ['unreasoning', 'syllables', 1],
#  ['label', 'prick', 1],
#  ['scotland', 'particulars', 1],
#  ['lodgings', 'lodgfngs', 0],
#  ['believing', 'lelieving', 0],
#  ['device', 'withdrawn', 1],
#  ['betraying', 'sidelights', 1],
#  ['tears', 'upraised', 1],
#  ['bags', 'baqs', 0],
#  ['encouraging', 'encouraxing', 0],
#  ['recoil', 'recxil', 0],
#  ['locked', 'effusive', 1],
#  ['comparing', 'comparilg', 0],
#  ['answers', 'companion', 1],
#  ['aldersgate', 'lldersgate', 0],
#  ['footpaths', 'footpatxhs', 0],
#  ['deserts', 'deyerts', 0],
#  ['work', 'rk', 0],
#  ['imagine', 'lowliest', 1],
#  ['tankerville', 'fast', 1],
#  ['indulged', 'gesellschaft', 1],
#  ['ships', 'ghips', 0],
#  ['nodded', 'gift', 1],
#  ['crab', 'crbb', 0],
#  ['dispel', 'unique', 1],
#  ['sure', 'margins', 1],
#  ['mangled', 'mbngled', 0],
#  ['abandoned', 'abandonfed', 0],
#  ['travelled', 'travolled', 0],
#  ['immediate', 'recognising', 1],
#  ['policeman', 'drew', 1],
#  ['sternly', 'jsternly', 0],
#  ['humoured', 'teeth', 1],
#  ['extinguishes', 'extwinguishes', 0],
#  ['alteration', 'tightly', 1],
#  ['picture', 'pictrure', 0],
#  ['astonishment', 'astontshment', 0],
#  ['gleaming', 'prying', 1],
#  ['imploring', 'imoring', 0],
#  ['stethoscope', 'times', 1],
#  ['seared', 'turf', 1],
#  ['measures', 'measurfs', 0],
#  ['completed', 'comletd', 0],
#  ['stream', 'sdream', 0],
#  ['flame', 'mlafe', 0],
#  ['indications', 'indirations', 0],
#  ['qualities', 'qalties', 0],
#  ['impression', 'dimpression', 0],
#  ['chronicle', 'corporation', 1],
#  ['difficulty', 'shirt', 1],
#  ['clutches', 'cluthe', 0],
#  ['exactness', 'exactmess', 0],
#  ['rectify', 'consisted', 1],
#  ['poker', 'masterly', 1],
#  ['robberies', 'robberiqes', 0],
#  ['tobacconist', 'tobacchnist', 0],
#  ['available', 'sore', 1],
#  ['staying', 'confined', 1],
#  ['direction', 'direcpion', 0],
#  ['vanish', 'vwanish', 0],
#  ['observing', 'obseruing', 0],
#  ['cried', 'claspings', 1],
#  ['manageress', 'candle', 1],
#  ['neatness', 'thoughtful', 1],
#  ['thursday', 'anywhere', 1],
#  ['desire', 'desrre', 0],
#  ['soled', 'srled', 0],
#  ['salary', 'ealary', 0],
#  ['backed', 'xacked', 0],
#  ['assizes', 'assizea', 0],
#  ['caged', 'amusing', 1],
#  ['accidents', 'comfort', 1],
#  ['deceived', 'probed', 1],
#  ['amuse', 'fat', 1],
#  ['fonder', 'fondeor', 0],
#  ['daresay', 'surroundings', 1],
#  ['alternate', 'altecnate', 0],
#  ['actually', 'acrtually', 0],
#  ['smoothness', 'sxmoothness', 0],
#  ['undid', 'know', 1],
#  ['shillings', 'zhillings', 0],
#  ['established', 'lie', 1],
#  ['correspondent', 'corriespondent', 0],
#  ['prolong', 'prmolong', 0],
#  ['mahogany', 'mahoganqy', 0],
#  ['philanthropist', 'radius', 1],
#  ['questions', 'selections', 1],
#  ['been', 'besen', 0],
#  ['disgraceful', 'disgryaceful', 0],
#  ['narratives', 'arrativs', 0],
#  ['badly', 'aly', 0],
#  ['discriminate', 'discrihminate', 0],
#  ['opportunity', 'oppprtunity', 0],
#  ['climbing', 'bean', 1],
#  ['administration', 'adminiistration', 0],
#  ['shimmering', 'shimoering', 0],
#  ['changes', 'changrs', 0],
#  ['outdoor', 'heart', 1],
#  ['extending', 'extendping', 0],
#  ['share', 'mania', 1],
#  ['commander', 'cormmander', 0],
#  ['splendour', 'splendouu', 0],
#  ['londoners', 'lobdoners', 0],
#  ['measure', 'measube', 0],
#  ['niece', 'nimce', 0],
#  ['vitriol', 'vidtriol', 0],
#  ['larger', 'largey', 0],
#  ['lingering', 'ago', 1],
#  ['reward', 'ereward', 0],
#  ['precipitance', 'precipitadnce', 0],
#  ['emerald', 'emlerald', 0],
#  ['iota', 'hiota', 0],
#  ['exciting', 'senior', 1],
#  ['streatham', 'mtreathas', 0],
#  ['metallic', 'overstrung', 1],
#  ['elastic', 'straightened', 1],
#  ['crossed', 'untamed', 1],
#  ['coldly', 'toldly', 0],
#  ['advantage', 'wadvantage', 0],
#  ['uncovered', 'uncovecred', 0],
#  ['daubing', 'foremost', 1],
#  ['cushion', 'obligations', 1],
#  ['stepping', 'stepbing', 0],
#  ['suddenly', 'correct', 1],
#  ['derived', 'deryved', 0],
#  ['supplied', 'accounts', 1],
#  ['achieved', 'acheived', 0],
#  ['diary', 'dilry', 0],
#  ['flattered', 'flaittered', 0],
#  ['indirect', 'indirzect', 0],
#  ['coster', 'tire', 1],
#  ['correspondence', 'correspkondence', 0],
#  ['count', 'hay', 1],
#  ['overcome', 'ovrcom', 0],
#  ['resolve', 'rrsolve', 0],
#  ['madman', 'bought', 1],
#  ['reverse', 'revecse', 0],
#  ['mud', 'mrud', 0],
#  ['indeed', 'actress', 1],
#  ['water', 'wabter', 0],
#  ['fee', 'balzac', 1],
#  ['several', 'severkl', 0],
#  ['californian', 'californiah', 0],
#  ['regain', 'regagin', 0],
#  ['hansom', 'continues', 1],
#  ['barrow', 'rails', 1],
#  ['peter', 'pexter', 0],
#  ['further', 'finish', 1],
#  ['forecastle', 'fnorecastle', 0],
#  ['hailed', 'arrest', 1],
#  ['allegro', 'gathered', 1],
#  ['desired', 'cushions', 1],
#  ['lose', 'sturdy', 1],
#  ['terminated', 'termyinated', 0],
#  ['trick', 'trice', 0],
#  ['cordially', 'smear', 1],
#  ['streaked', 'wheels', 1],
#  ['dazed', 'dazed', 0],
#  ['neighbourhood', 'neighboyurhood', 0],
#  ['approached', 'approaczed', 0],
#  ['fear', 'lightning', 1],
#  ['candle', 'category', 1],
#  ['urging', 'urgiang', 0],
#  ['cough', 'coough', 0],
#  ['exists', 'vanished', 1],
#  ['talking', 'lking', 0],
#  ['accident', 'spectacle', 1],
#  ['production', 'ploduction', 0],
#  ['considerable', 'codsiderable', 0],
#  ['annoyed', 'equalled', 1],
#  ['vanishes', 'vanishpes', 0],
#  ['pressing', 'loosened', 1],
#  ['amuse', 'amubse', 0],
#  ['identify', 'idhntify', 0],
#  ['commonplace', 'characteristic', 1],
#  ['affairs', 'buttoning', 1],
#  ['facilitate', 'facilitaite', 0],
#  ['cheetah', 'heeta', 0],
#  ['divan', 'flourished', 1],
#  ['expenses', 'george', 1],
#  ['indignation', 'indihgnation', 0],
#  ['squander', 'squunder', 0],
#  ['satisfaction', 'sutisfaction', 0],
#  ['thirty', 'thircy', 0],
#  ['spouting', 'soting', 0],
#  ['trivial', 'disguises', 1],
#  ['carpenter', 'carpenmter', 0],
#  ['confide', 'coffide', 0],
#  ['everywhere', 'ejverywhere', 0],
#  ['shade', 'shale', 0],
#  ['swan', 'siwan', 0],
#  ...]

# %%
df = pd.DataFrame(combined_data, columns=["Correct Word", "Incorrect Word", "Target"])

# %%
len(df)
# Out:
# 5983906

# %%
df.groupby(["Target"])["Target"].count()
# Out:
# Target
# 0    3180380
# 1    2803526
# Name: Target, dtype: int64

# %%
print(df.groupby(["Correct Word","Target"]).count().sort_values(by=["Correct Word","Target"]))
# Out:
#                      Incorrect Word
# Correct Word Target
# abandoned    0                  520
#              1                  381
# abandons     0                  455
#              1                  307
# abbots       0                  327
# ...                             ...
# zest         1                  388
# zigzag       0                  330
#              1                  324
# zip          0                  158
#              1                  312
#
# [16002 rows x 1 columns]

# %%
df.to_csv("./datasets/Specific Combinations.csv",index=False)

# %%
# pd.read_csv("Custom Dict Dataset.csv")
